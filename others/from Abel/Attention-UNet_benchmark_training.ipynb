# %%
import os
from natsort import natsorted
import random
import tifffile as tiff
import cv2
from matplotlib import pyplot as plt
import numpy as np

import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
img_dir = "new_dataset/images/"
mask_dir = "new_dataset/masks/"

#img_dir = "new_dataset_Italy/images/"
#mask_dir = "new_dataset_Italy/masks/"

img_list = os.listdir(img_dir)
img_list=natsorted(img_list)

msk_list = os.listdir(mask_dir)
msk_list=natsorted(msk_list)

num_images = len(os.listdir(img_dir))

# %%
def reading_images(root_path, files):
    images=[]
    for file in files:
        img=tiff.imread(root_path+file)
        #print(img[:10,0])
        images.append(img)
    return images

# %%
masks=reading_images(mask_dir, msk_list)
masks_ar=np.array(masks)
masks_ar=np.expand_dims(masks_ar, axis=-1)

imgs=reading_images(img_dir, img_list)
imgs_ar=np.array(imgs)

# %%
imgs_ar.shape, masks_ar.shape
# Out:
# ((1303, 128, 128, 14), (1303, 128, 128, 1))

# %%
def min_max_scaler_image(image):
    normalized_image = np.zeros_like(image)
    for i in range(image.shape[2]):
        max_value=np.max(image[:,:,i])
        min_value=np.min(image[:,:,i])
        normalized_image[:,:,i] = image[:,:,i]/ max_value
        #normalized_image[:,:,i] = normalized_image[:,:,i] + 0.5
        #normalized_image[:,:,i] = np.clip(normalized_image[:,:,i], 0, 1)
    return normalized_image

# %%
def scale_normalize_image(image, means, stds):
    normalized_image = np.zeros_like(image)
    for i in range(image.shape[2]):
        normalized_image[:,:,i] = (image[:,:,i] - means[i]) / (2 * stds[i])
        normalized_image[:,:,i] = normalized_image[:,:,i] + 0.5
        normalized_image[:,:,i] = np.clip(normalized_image[:,:,i], 0, 1)
    return normalized_image

# %%
means=[]
stds=[]
for i in range(0,14):
    print(np.mean(imgs_ar[:,:,:,i]), np.max(imgs_ar[:,:,:,i]), np.min(imgs_ar[:,:,:,i]), np.std(imgs_ar[:,:,:,i]))
    means.append(np.mean(imgs_ar[:,:,:,i]))
    stds.append(np.std(imgs_ar[:,:,:,i]))
# Out:
# 1052.0874 1905.0 0.0 275.63873
# 786.344 3638.0 0.0 219.11479
# 675.8054 3652.0 0.0 205.79753
# 468.578 4746.0 0.0 216.42885
# 759.43427 3624.0 0.0 276.08264
# 1726.8557 4256.0 0.0 584.2288
# 2134.1873 5584.0 0.0 735.80164
# 2175.0952 6059.0 0.0 799.70184
# 994.03235 2989.0 0.0 413.959
# 14.251601 223.0 0.0 12.503192
# 1372.7716 5433.0 0.0 603.5555
# 668.4369 10459.0 0.0 394.17944
# 18.941736 77.98855 0.0 11.342175
# 572.7976 2431.891 0.0 425.39337

# %%
imgs_norm=[]
for img in imgs_ar:
#    img_std=min_max_scaler_image(img)
    img_std=scale_normalize_image(img, means, stds)
    imgs_norm.append(img_std)  
imgs_norm=np.array(imgs_norm)

imgs_ar=imgs_norm

# %%
n_random_samples  = 6
n_bands = 14  # Now we have 14 bands in total

#fig, axs = plt.subplots(n_samples_to_plot, 12, figsize=(20, 16))  # 1 RGB composite + 11 individual bands + 1 mask

# Generate random sample indices
random_indices = np.random.choice(np.arange(imgs_ar.shape[0]), size=n_random_samples, replace=False)

# Plotting the random samples
fig, axs = plt.subplots(n_random_samples, 12, figsize=(20, 16))  # Layout configuration

for i, sample_idx in enumerate(random_indices):
    # Create an RGB composite image from the first 3 bands for the selected sample
    rgb_image = imgs_ar[sample_idx, :, :, :3]
    rgb_image /= rgb_image.max()  # Normalizing to [0, 1] for displaying as RGB
    axs[i, 0].imshow(rgb_image)
    axs[i, 0].axis('off')  # Hide axis
    if i == 0:
        axs[i, 0].set_title('RGB Composite', size='large')
    
    for band_idx in range(3, n_bands):  # Starting from the 4th band
        axs[i, band_idx-2].imshow(imgs_ar[sample_idx, :, :, band_idx])#, cmap='gray')
        axs[i, band_idx-2].axis('off')  # Hide axis
        if i == 0:
            axs[0, band_idx-2].set_title(f'Band {band_idx+1}', size='large')

    # Plotting the segmentation mask for the selected sample
    axs[i, 11].imshow(masks_ar[sample_idx, :, :], cmap='gray')
    axs[i, 11].axis('off')
    if i == 0:
        axs[0, 11].set_title('Segmentation Mask', size='large')

plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs_ar, masks_ar, test_size=0.3, random_state=42)

# %%
np.unique(y_test), np.unique(y_train)
# Out:
# (array([0, 1], dtype=uint8), array([0, 1], dtype=uint8))

# %%
from keras_unet_collection import models
from keras_unet_collection import losses
import segmentation_models as sm
from tensorflow.python.framework import ops
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow import keras
from datetime import datetime
# Out:
# Segmentation Models: using `keras` framework.

# %%
model=models.att_unet_2d((X_train.shape[-3], X_train.shape[-2], X_train.shape[-1]), [64, 128, 256, 512, 1024], n_labels=1,
                           stack_num_down=2, stack_num_up=2,
                           activation='ReLU', atten_activation='ReLU', attention='add', output_activation='Sigmoid', 
                           batch_norm=True, pool='max', unpool='nearest', name='attunet')

# %%
model.summary()
# Out:
# Model: "attunet_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 4)]
#
#  attunet_down0_0 (Conv2D)       (None, 128, 128, 64  8064        ['input_1[0][0]']
#                                 )
#
#  attunet_down0_0_bn (BatchNorma  (None, 128, 128, 64  256        ['attunet_down0_0[0][0]']
#  lization)                      )
#
#  attunet_down0_0_activation (Re  (None, 128, 128, 64  0          ['attunet_down0_0_bn[0][0]']
#  LU)                            )
#
#  attunet_down0_1 (Conv2D)       (None, 128, 128, 64  36864       ['attunet_down0_0_activation[0][0
#                                 )                                ]']
#
#  attunet_down0_1_bn (BatchNorma  (None, 128, 128, 64  256        ['attunet_down0_1[0][0]']
#  lization)                      )
#
#  attunet_down0_1_activation (Re  (None, 128, 128, 64  0          ['attunet_down0_1_bn[0][0]']
#  LU)                            )
#
#  attunet_down1_encode_maxpool (  (None, 64, 64, 64)  0           ['attunet_down0_1_activation[0][0
#  MaxPooling2D)                                                   ]']
#
#  attunet_down1_conv_0 (Conv2D)  (None, 64, 64, 128)  73728       ['attunet_down1_encode_maxpool[0]
#                                                                  [0]']
#
#  attunet_down1_conv_0_bn (Batch  (None, 64, 64, 128)  512        ['attunet_down1_conv_0[0][0]']
#  Normalization)
#
#  attunet_down1_conv_0_activatio  (None, 64, 64, 128)  0          ['attunet_down1_conv_0_bn[0][0]']
#  n (ReLU)
#
#  attunet_down1_conv_1 (Conv2D)  (None, 64, 64, 128)  147456      ['attunet_down1_conv_0_activation
#                                                                  [0][0]']
#
#  attunet_down1_conv_1_bn (Batch  (None, 64, 64, 128)  512        ['attunet_down1_conv_1[0][0]']
#  Normalization)
#
#  attunet_down1_conv_1_activatio  (None, 64, 64, 128)  0          ['attunet_down1_conv_1_bn[0][0]']
#  n (ReLU)
#
#  attunet_down2_encode_maxpool (  (None, 32, 32, 128)  0          ['attunet_down1_conv_1_activation
#  MaxPooling2D)                                                   [0][0]']
#
#  attunet_down2_conv_0 (Conv2D)  (None, 32, 32, 256)  294912      ['attunet_down2_encode_maxpool[0]
#                                                                  [0]']
#
#  attunet_down2_conv_0_bn (Batch  (None, 32, 32, 256)  1024       ['attunet_down2_conv_0[0][0]']
#  Normalization)
#
#  attunet_down2_conv_0_activatio  (None, 32, 32, 256)  0          ['attunet_down2_conv_0_bn[0][0]']
#  n (ReLU)
#
#  attunet_down2_conv_1 (Conv2D)  (None, 32, 32, 256)  589824      ['attunet_down2_conv_0_activation
#                                                                  [0][0]']
#
#  attunet_down2_conv_1_bn (Batch  (None, 32, 32, 256)  1024       ['attunet_down2_conv_1[0][0]']
#  Normalization)
#
#  attunet_down2_conv_1_activatio  (None, 32, 32, 256)  0          ['attunet_down2_conv_1_bn[0][0]']
#  n (ReLU)
#
#  attunet_down3_encode_maxpool (  (None, 16, 16, 256)  0          ['attunet_down2_conv_1_activation
#  MaxPooling2D)                                                   [0][0]']
#
#  attunet_down3_conv_0 (Conv2D)  (None, 16, 16, 512)  1179648     ['attunet_down3_encode_maxpool[0]
#                                                                  [0]']
#
#  attunet_down3_conv_0_bn (Batch  (None, 16, 16, 512)  2048       ['attunet_down3_conv_0[0][0]']
#  Normalization)
#
#  attunet_down3_conv_0_activatio  (None, 16, 16, 512)  0          ['attunet_down3_conv_0_bn[0][0]']
#  n (ReLU)
#
#  attunet_down3_conv_1 (Conv2D)  (None, 16, 16, 512)  2359296     ['attunet_down3_conv_0_activation
#                                                                  [0][0]']
#
#  attunet_down3_conv_1_bn (Batch  (None, 16, 16, 512)  2048       ['attunet_down3_conv_1[0][0]']
#  Normalization)
#
#  attunet_down3_conv_1_activatio  (None, 16, 16, 512)  0          ['attunet_down3_conv_1_bn[0][0]']
#  n (ReLU)
#
#  attunet_down4_encode_maxpool (  (None, 8, 8, 512)   0           ['attunet_down3_conv_1_activation
#  MaxPooling2D)                                                   [0][0]']
#
#  attunet_down4_conv_0 (Conv2D)  (None, 8, 8, 1024)   4718592     ['attunet_down4_encode_maxpool[0]
#                                                                  [0]']
#
#  attunet_down4_conv_0_bn (Batch  (None, 8, 8, 1024)  4096        ['attunet_down4_conv_0[0][0]']
#  Normalization)
#
#  attunet_down4_conv_0_activatio  (None, 8, 8, 1024)  0           ['attunet_down4_conv_0_bn[0][0]']
#  n (ReLU)
#
#  attunet_down4_conv_1 (Conv2D)  (None, 8, 8, 1024)   9437184     ['attunet_down4_conv_0_activation
#                                                                  [0][0]']
#
#  attunet_down4_conv_1_bn (Batch  (None, 8, 8, 1024)  4096        ['attunet_down4_conv_1[0][0]']
#  Normalization)
#
#  attunet_down4_conv_1_activatio  (None, 8, 8, 1024)  0           ['attunet_down4_conv_1_bn[0][0]']
#  n (ReLU)
#
#  attunet_up0_decode_unpool (UpS  (None, 16, 16, 1024  0          ['attunet_down4_conv_1_activation
#  ampling2D)                     )                                [0][0]']
#
#  attunet_up0_att_theta_x (Conv2  (None, 16, 16, 256)  131328     ['attunet_down3_conv_1_activation
#  D)                                                              [0][0]']
#
#  attunet_up0_att_phi_g (Conv2D)  (None, 16, 16, 256)  262400     ['attunet_up0_decode_unpool[0][0]
#                                                                  ']
#
#  attunet_up0_att_add (Add)      (None, 16, 16, 256)  0           ['attunet_up0_att_theta_x[0][0]',
#                                                                   'attunet_up0_att_phi_g[0][0]']
#
#  attunet_up0_att_activation (Re  (None, 16, 16, 256)  0          ['attunet_up0_att_add[0][0]']
#  LU)
#
#  attunet_up0_att_psi_f (Conv2D)  (None, 16, 16, 1)   257         ['attunet_up0_att_activation[0][0
#                                                                  ]']
#
#  attunet_up0_att_sigmoid (Activ  (None, 16, 16, 1)   0           ['attunet_up0_att_psi_f[0][0]']
#  ation)
#
#  attunet_up0_att_masking (Multi  (None, 16, 16, 512)  0          ['attunet_down3_conv_1_activation
#  ply)                                                            [0][0]',
#                                                                   'attunet_up0_att_sigmoid[0][0]']
#
#  attunet_up0_concat (Concatenat  (None, 16, 16, 1536  0          ['attunet_up0_decode_unpool[0][0]
#  e)                             )                                ',
#                                                                   'attunet_up0_att_masking[0][0]']
#
#  attunet_up0_conv_after_concat_  (None, 16, 16, 512)  7077888    ['attunet_up0_concat[0][0]']
#  0 (Conv2D)
#
#  attunet_up0_conv_after_concat_  (None, 16, 16, 512)  2048       ['attunet_up0_conv_after_concat_0
#  0_bn (BatchNormalization)                                       [0][0]']
#
#  attunet_up0_conv_after_concat_  (None, 16, 16, 512)  0          ['attunet_up0_conv_after_concat_0
#  0_activation (ReLU)                                             _bn[0][0]']
#
#  attunet_up0_conv_after_concat_  (None, 16, 16, 512)  2359296    ['attunet_up0_conv_after_concat_0
#  1 (Conv2D)                                                      _activation[0][0]']
#
#  attunet_up0_conv_after_concat_  (None, 16, 16, 512)  2048       ['attunet_up0_conv_after_concat_1
#  1_bn (BatchNormalization)                                       [0][0]']
#
#  attunet_up0_conv_after_concat_  (None, 16, 16, 512)  0          ['attunet_up0_conv_after_concat_1
#  1_activation (ReLU)                                             _bn[0][0]']
#
#  attunet_up1_decode_unpool (UpS  (None, 32, 32, 512)  0          ['attunet_up0_conv_after_concat_1
#  ampling2D)                                                      _activation[0][0]']
#
#  attunet_up1_att_theta_x (Conv2  (None, 32, 32, 128)  32896      ['attunet_down2_conv_1_activation
#  D)                                                              [0][0]']
#
#  attunet_up1_att_phi_g (Conv2D)  (None, 32, 32, 128)  65664      ['attunet_up1_decode_unpool[0][0]
#                                                                  ']
#
#  attunet_up1_att_add (Add)      (None, 32, 32, 128)  0           ['attunet_up1_att_theta_x[0][0]',
#                                                                   'attunet_up1_att_phi_g[0][0]']
#
#  attunet_up1_att_activation (Re  (None, 32, 32, 128)  0          ['attunet_up1_att_add[0][0]']
#  LU)
#
#  attunet_up1_att_psi_f (Conv2D)  (None, 32, 32, 1)   129         ['attunet_up1_att_activation[0][0
#                                                                  ]']
#
#  attunet_up1_att_sigmoid (Activ  (None, 32, 32, 1)   0           ['attunet_up1_att_psi_f[0][0]']
#  ation)
#
#  attunet_up1_att_masking (Multi  (None, 32, 32, 256)  0          ['attunet_down2_conv_1_activation
#  ply)                                                            [0][0]',
#                                                                   'attunet_up1_att_sigmoid[0][0]']
#
#  attunet_up1_concat (Concatenat  (None, 32, 32, 768)  0          ['attunet_up1_decode_unpool[0][0]
#  e)                                                              ',
#                                                                   'attunet_up1_att_masking[0][0]']
#
#  attunet_up1_conv_after_concat_  (None, 32, 32, 256)  1769472    ['attunet_up1_concat[0][0]']
#  0 (Conv2D)
#
#  attunet_up1_conv_after_concat_  (None, 32, 32, 256)  1024       ['attunet_up1_conv_after_concat_0
#  0_bn (BatchNormalization)                                       [0][0]']
#
#  attunet_up1_conv_after_concat_  (None, 32, 32, 256)  0          ['attunet_up1_conv_after_concat_0
#  0_activation (ReLU)                                             _bn[0][0]']
#
#  attunet_up1_conv_after_concat_  (None, 32, 32, 256)  589824     ['attunet_up1_conv_after_concat_0
#  1 (Conv2D)                                                      _activation[0][0]']
#
#  attunet_up1_conv_after_concat_  (None, 32, 32, 256)  1024       ['attunet_up1_conv_after_concat_1
#  1_bn (BatchNormalization)                                       [0][0]']
#
#  attunet_up1_conv_after_concat_  (None, 32, 32, 256)  0          ['attunet_up1_conv_after_concat_1
#  1_activation (ReLU)                                             _bn[0][0]']
#
#  attunet_up2_decode_unpool (UpS  (None, 64, 64, 256)  0          ['attunet_up1_conv_after_concat_1
#  ampling2D)                                                      _activation[0][0]']
#
#  attunet_up2_att_theta_x (Conv2  (None, 64, 64, 64)  8256        ['attunet_down1_conv_1_activation
#  D)                                                              [0][0]']
#
#  attunet_up2_att_phi_g (Conv2D)  (None, 64, 64, 64)  16448       ['attunet_up2_decode_unpool[0][0]
#                                                                  ']
#
#  attunet_up2_att_add (Add)      (None, 64, 64, 64)   0           ['attunet_up2_att_theta_x[0][0]',
#                                                                   'attunet_up2_att_phi_g[0][0]']
#
#  attunet_up2_att_activation (Re  (None, 64, 64, 64)  0           ['attunet_up2_att_add[0][0]']
#  LU)
#
#  attunet_up2_att_psi_f (Conv2D)  (None, 64, 64, 1)   65          ['attunet_up2_att_activation[0][0
#                                                                  ]']
#
#  attunet_up2_att_sigmoid (Activ  (None, 64, 64, 1)   0           ['attunet_up2_att_psi_f[0][0]']
#  ation)
#
#  attunet_up2_att_masking (Multi  (None, 64, 64, 128)  0          ['attunet_down1_conv_1_activation
#  ply)                                                            [0][0]',
#                                                                   'attunet_up2_att_sigmoid[0][0]']
#
#  attunet_up2_concat (Concatenat  (None, 64, 64, 384)  0          ['attunet_up2_decode_unpool[0][0]
#  e)                                                              ',
#                                                                   'attunet_up2_att_masking[0][0]']
#
#  attunet_up2_conv_after_concat_  (None, 64, 64, 128)  442368     ['attunet_up2_concat[0][0]']
#  0 (Conv2D)
#
#  attunet_up2_conv_after_concat_  (None, 64, 64, 128)  512        ['attunet_up2_conv_after_concat_0
#  0_bn (BatchNormalization)                                       [0][0]']
#
#  attunet_up2_conv_after_concat_  (None, 64, 64, 128)  0          ['attunet_up2_conv_after_concat_0
#  0_activation (ReLU)                                             _bn[0][0]']
#
#  attunet_up2_conv_after_concat_  (None, 64, 64, 128)  147456     ['attunet_up2_conv_after_concat_0
#  1 (Conv2D)                                                      _activation[0][0]']
#
#  attunet_up2_conv_after_concat_  (None, 64, 64, 128)  512        ['attunet_up2_conv_after_concat_1
#  1_bn (BatchNormalization)                                       [0][0]']
#
#  attunet_up2_conv_after_concat_  (None, 64, 64, 128)  0          ['attunet_up2_conv_after_concat_1
#  1_activation (ReLU)                                             _bn[0][0]']
#
#  attunet_up3_decode_unpool (UpS  (None, 128, 128, 12  0          ['attunet_up2_conv_after_concat_1
#  ampling2D)                     8)                               _activation[0][0]']
#
#  attunet_up3_att_theta_x (Conv2  (None, 128, 128, 32  2080       ['attunet_down0_1_activation[0][0
#  D)                             )                                ]']
#
#  attunet_up3_att_phi_g (Conv2D)  (None, 128, 128, 32  4128       ['attunet_up3_decode_unpool[0][0]
#                                 )                                ']
#
#  attunet_up3_att_add (Add)      (None, 128, 128, 32  0           ['attunet_up3_att_theta_x[0][0]',
#                                 )                                 'attunet_up3_att_phi_g[0][0]']
#
#  attunet_up3_att_activation (Re  (None, 128, 128, 32  0          ['attunet_up3_att_add[0][0]']
#  LU)                            )
#
#  attunet_up3_att_psi_f (Conv2D)  (None, 128, 128, 1)  33         ['attunet_up3_att_activation[0][0
#                                                                  ]']
#
#  attunet_up3_att_sigmoid (Activ  (None, 128, 128, 1)  0          ['attunet_up3_att_psi_f[0][0]']
#  ation)
#
#  attunet_up3_att_masking (Multi  (None, 128, 128, 64  0          ['attunet_down0_1_activation[0][0
#  ply)                           )                                ]',
#                                                                   'attunet_up3_att_sigmoid[0][0]']
#
#  attunet_up3_concat (Concatenat  (None, 128, 128, 19  0          ['attunet_up3_decode_unpool[0][0]
#  e)                             2)                               ',
#                                                                   'attunet_up3_att_masking[0][0]']
#
#  attunet_up3_conv_after_concat_  (None, 128, 128, 64  110592     ['attunet_up3_concat[0][0]']
#  0 (Conv2D)                     )
#
#  attunet_up3_conv_after_concat_  (None, 128, 128, 64  256        ['attunet_up3_conv_after_concat_0
#  0_bn (BatchNormalization)      )                                [0][0]']
#
#  attunet_up3_conv_after_concat_  (None, 128, 128, 64  0          ['attunet_up3_conv_after_concat_0
#  0_activation (ReLU)            )                                _bn[0][0]']
#
#  attunet_up3_conv_after_concat_  (None, 128, 128, 64  36864      ['attunet_up3_conv_after_concat_0
#  1 (Conv2D)                     )                                _activation[0][0]']
#
#  attunet_up3_conv_after_concat_  (None, 128, 128, 64  256        ['attunet_up3_conv_after_concat_1
#  1_bn (BatchNormalization)      )                                [0][0]']
#
#  attunet_up3_conv_after_concat_  (None, 128, 128, 64  0          ['attunet_up3_conv_after_concat_1
#  1_activation (ReLU)            )                                _bn[0][0]']
#
#  attunet_output (Conv2D)        (None, 128, 128, 1)  65          ['attunet_up3_conv_after_concat_1
#                                                                  _activation[0][0]']
#
#  attunet_output_activation (Act  (None, 128, 128, 1)  0          ['attunet_output[0][0]']
#  ivation)
#
# ==================================================================================================
# Total params: 31,926,629
# Trainable params: 31,914,853
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
def jaccard_coef(y_true, y_pred):
    # Cast tensors to float32
    y_true_f = tf.cast(tf.keras.backend.flatten(y_true), tf.float32)
    y_pred_f = tf.cast(tf.keras.backend.flatten(y_pred), tf.float32)
    
    # Calculate the intersection
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    
    # Calculate the sum of both predictions and true values, then subtract intersection to get union
    union = tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection
    
    # Smooth term to avoid division by zero
    smooth = 1.0
    
    # Compute Jaccard index
    jaccard_index = (intersection + smooth) / (union + smooth)
    return jaccard_index

def jaccard_coef_loss(y_true, y_pred):
    return -jaccard_coef(y_true, y_pred)

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# %%
filepath = ("Models/"+model.name+"_best-model.hdf5")

# %%
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
reduce_lr = ReduceLROnPlateau(monitor="loss", factor=0.3, patience=10, verbose=1, cooldown=10, min_lr=1e-5)
lr_shceduler = LearningRateScheduler(lambda _, lr: lr * np.exp(-0.01), verbose=1)
tensorboard = keras.callbacks.TensorBoard("logs/1_r2a", update_freq=1)

callbacks_list = [reduce_lr, lr_shceduler, tensorboard, checkpoint]

# %%
model.compile(#optimizer=keras.optimizers.SGD(lr=1e-3), 
#              optimizer = 'adam',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#              loss = 'binary_crossentropy',
              loss=jaccard_coef_loss,  
              #loss=losses.iou_seg,
#              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#              loss=tf.keras.losses.BinaryFocalCrossentropy(gamma=2.0, from_logits=True),
              metrics=['accuracy', 
                       losses.iou_seg, 
                       tf.keras.metrics.MeanIoU(num_classes=2), 
                       tf.keras.metrics.Recall(), 
                       sm.metrics.iou_score,
                       tf.keras.metrics.Precision()])

# %%
callback = [tf.keras.callbacks.LearningRateScheduler(scheduler), checkpoint]

# %%
start1 = datetime.now() 

model_history = model.fit(X_train, y_train, 
                    batch_size = 8, 
                    verbose=1, 
                    epochs=150, 
                    validation_data=(X_test, y_test),
                    #callbacks=callbacks_list,
                    callbacks=[callback],
                    shuffle=False)
#model.save(model.name+'.hdf5')
stop1 = datetime.now()
execution_time_model = stop1-start1
print(model.name+" execution time is: ", execution_time_model)
# Out:
# Epoch 1/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0126 - accuracy: 0.8348 - iou_seg: 0.9875 - mean_io_u: 0.5044 - recall: 0.5366 - iou_score: 0.0125 - precision: 0.0139
# Epoch 1: val_loss improved from inf to -0.00981, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 28s 130ms/step - loss: -0.0126 - accuracy: 0.8348 - iou_seg: 0.9875 - mean_io_u: 0.5044 - recall: 0.5366 - iou_score: 0.0125 - precision: 0.0139 - val_loss: -0.0098 - val_accuracy: 0.9694 - val_iou_seg: 0.9903 - val_mean_io_u: 0.4979 - val_recall: 0.1417 - val_iou_score: 0.0097 - val_precision: 0.0219 - lr: 0.0010
# Epoch 2/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0253 - accuracy: 0.9756 - iou_seg: 0.9750 - mean_io_u: 0.5005 - recall: 0.1766 - iou_score: 0.0250 - precision: 0.0351
# Epoch 2: val_loss did not improve from -0.00981
# 114/114 [==============================] - 11s 93ms/step - loss: -0.0253 - accuracy: 0.9756 - iou_seg: 0.9750 - mean_io_u: 0.5005 - recall: 0.1766 - iou_score: 0.0250 - precision: 0.0351 - val_loss: -0.0024 - val_accuracy: 0.9957 - val_iou_seg: 0.9999 - val_mean_io_u: 0.4979 - val_recall: 1.8326e-04 - val_iou_score: 1.2414e-04 - val_precision: 0.0210 - lr: 0.0010
# Epoch 3/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0495 - accuracy: 0.9853 - iou_seg: 0.9511 - mean_io_u: 0.5093 - recall: 0.1844 - iou_score: 0.0489 - precision: 0.0659
# Epoch 3: val_loss did not improve from -0.00981
# 114/114 [==============================] - 11s 93ms/step - loss: -0.0495 - accuracy: 0.9853 - iou_seg: 0.9511 - mean_io_u: 0.5093 - recall: 0.1844 - iou_score: 0.0489 - precision: 0.0659 - val_loss: -0.0057 - val_accuracy: 0.4050 - val_iou_seg: 0.9943 - val_mean_io_u: 0.3131 - val_recall: 0.8158 - val_iou_score: 0.0057 - val_precision: 0.0058 - lr: 0.0010
# Epoch 4/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0398 - accuracy: 0.9833 - iou_seg: 0.9610 - mean_io_u: 0.5093 - recall: 0.1572 - iou_score: 0.0390 - precision: 0.0491
# Epoch 4: val_loss improved from -0.00981 to -0.04258, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.0398 - accuracy: 0.9833 - iou_seg: 0.9610 - mean_io_u: 0.5093 - recall: 0.1572 - iou_score: 0.0390 - precision: 0.0491 - val_loss: -0.0426 - val_accuracy: 0.9915 - val_iou_seg: 0.9586 - val_mean_io_u: 0.5040 - val_recall: 0.1031 - val_iou_score: 0.0414 - val_precision: 0.0857 - lr: 0.0010
# Epoch 5/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0503 - accuracy: 0.9882 - iou_seg: 0.9504 - mean_io_u: 0.5109 - recall: 0.1404 - iou_score: 0.0496 - precision: 0.0690
# Epoch 5: val_loss did not improve from -0.04258
# 114/114 [==============================] - 11s 93ms/step - loss: -0.0503 - accuracy: 0.9882 - iou_seg: 0.9504 - mean_io_u: 0.5109 - recall: 0.1404 - iou_score: 0.0496 - precision: 0.0690 - val_loss: -0.0239 - val_accuracy: 0.9940 - val_iou_seg: 0.9777 - val_mean_io_u: 0.5045 - val_recall: 0.0466 - val_iou_score: 0.0223 - val_precision: 0.0911 - lr: 0.0010
# Epoch 6/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0490 - accuracy: 0.9905 - iou_seg: 0.9518 - mean_io_u: 0.5127 - recall: 0.1276 - iou_score: 0.0482 - precision: 0.0865
# Epoch 6: val_loss did not improve from -0.04258
# 114/114 [==============================] - 11s 93ms/step - loss: -0.0490 - accuracy: 0.9905 - iou_seg: 0.9518 - mean_io_u: 0.5127 - recall: 0.1276 - iou_score: 0.0482 - precision: 0.0865 - val_loss: -0.0399 - val_accuracy: 0.9954 - val_iou_seg: 0.9619 - val_mean_io_u: 0.4992 - val_recall: 0.0619 - val_iou_score: 0.0381 - val_precision: 0.2873 - lr: 0.0010
# Epoch 7/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0657 - accuracy: 0.9913 - iou_seg: 0.9352 - mean_io_u: 0.5206 - recall: 0.1577 - iou_score: 0.0648 - precision: 0.1171
# Epoch 7: val_loss did not improve from -0.04258
# 114/114 [==============================] - 11s 92ms/step - loss: -0.0657 - accuracy: 0.9913 - iou_seg: 0.9352 - mean_io_u: 0.5206 - recall: 0.1577 - iou_score: 0.0648 - precision: 0.1171 - val_loss: -0.0171 - val_accuracy: 0.8670 - val_iou_seg: 0.9830 - val_mean_io_u: 0.4664 - val_recall: 0.5359 - val_iou_score: 0.0170 - val_precision: 0.0171 - lr: 0.0010
# Epoch 8/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0721 - accuracy: 0.9908 - iou_seg: 0.9287 - mean_io_u: 0.5264 - recall: 0.1792 - iou_score: 0.0713 - precision: 0.1202
# Epoch 8: val_loss improved from -0.04258 to -0.06996, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.0721 - accuracy: 0.9908 - iou_seg: 0.9287 - mean_io_u: 0.5264 - recall: 0.1792 - iou_score: 0.0713 - precision: 0.1202 - val_loss: -0.0700 - val_accuracy: 0.9942 - val_iou_seg: 0.9316 - val_mean_io_u: 0.5196 - val_recall: 0.1178 - val_iou_score: 0.0684 - val_precision: 0.1957 - lr: 0.0010
# Epoch 9/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0756 - accuracy: 0.9918 - iou_seg: 0.9253 - mean_io_u: 0.5304 - recall: 0.1722 - iou_score: 0.0747 - precision: 0.1376
# Epoch 9: val_loss did not improve from -0.06996
# 114/114 [==============================] - 11s 94ms/step - loss: -0.0756 - accuracy: 0.9918 - iou_seg: 0.9253 - mean_io_u: 0.5304 - recall: 0.1722 - iou_score: 0.0747 - precision: 0.1376 - val_loss: -0.0654 - val_accuracy: 0.9875 - val_iou_seg: 0.9356 - val_mean_io_u: 0.5305 - val_recall: 0.2183 - val_iou_score: 0.0644 - val_precision: 0.0925 - lr: 0.0010
# Epoch 10/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0788 - accuracy: 0.9918 - iou_seg: 0.9220 - mean_io_u: 0.5338 - recall: 0.1805 - iou_score: 0.0780 - precision: 0.1409
# Epoch 10: val_loss improved from -0.06996 to -0.07047, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.0788 - accuracy: 0.9918 - iou_seg: 0.9220 - mean_io_u: 0.5338 - recall: 0.1805 - iou_score: 0.0780 - precision: 0.1409 - val_loss: -0.0705 - val_accuracy: 0.9946 - val_iou_seg: 0.9310 - val_mean_io_u: 0.5233 - val_recall: 0.1159 - val_iou_score: 0.0690 - val_precision: 0.2310 - lr: 0.0010
# Epoch 11/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0853 - accuracy: 0.9916 - iou_seg: 0.9155 - mean_io_u: 0.5392 - recall: 0.2010 - iou_score: 0.0845 - precision: 0.1473
# Epoch 11: val_loss did not improve from -0.07047
# 114/114 [==============================] - 11s 93ms/step - loss: -0.0853 - accuracy: 0.9916 - iou_seg: 0.9155 - mean_io_u: 0.5392 - recall: 0.2010 - iou_score: 0.0845 - precision: 0.1473 - val_loss: -0.0598 - val_accuracy: 0.9947 - val_iou_seg: 0.9420 - val_mean_io_u: 0.5166 - val_recall: 0.0940 - val_iou_score: 0.0580 - val_precision: 0.2213 - lr: 9.0484e-04
# Epoch 12/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0876 - accuracy: 0.9925 - iou_seg: 0.9133 - mean_io_u: 0.5369 - recall: 0.1891 - iou_score: 0.0867 - precision: 0.1699
# Epoch 12: val_loss improved from -0.07047 to -0.07303, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.0876 - accuracy: 0.9925 - iou_seg: 0.9133 - mean_io_u: 0.5369 - recall: 0.1891 - iou_score: 0.0867 - precision: 0.1699 - val_loss: -0.0730 - val_accuracy: 0.9916 - val_iou_seg: 0.9282 - val_mean_io_u: 0.5327 - val_recall: 0.1775 - val_iou_score: 0.0718 - val_precision: 0.1338 - lr: 8.1873e-04
# Epoch 13/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0884 - accuracy: 0.9919 - iou_seg: 0.9124 - mean_io_u: 0.5402 - recall: 0.2020 - iou_score: 0.0876 - precision: 0.1560
# Epoch 13: val_loss improved from -0.07303 to -0.07553, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.0884 - accuracy: 0.9919 - iou_seg: 0.9124 - mean_io_u: 0.5402 - recall: 0.2020 - iou_score: 0.0876 - precision: 0.1560 - val_loss: -0.0755 - val_accuracy: 0.9927 - val_iou_seg: 0.9259 - val_mean_io_u: 0.5322 - val_recall: 0.1608 - val_iou_score: 0.0741 - val_precision: 0.1558 - lr: 7.4082e-04
# Epoch 14/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0951 - accuracy: 0.9921 - iou_seg: 0.9058 - mean_io_u: 0.5454 - recall: 0.2149 - iou_score: 0.0942 - precision: 0.1709
# Epoch 14: val_loss improved from -0.07553 to -0.07674, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 12s 108ms/step - loss: -0.0951 - accuracy: 0.9921 - iou_seg: 0.9058 - mean_io_u: 0.5454 - recall: 0.2149 - iou_score: 0.0942 - precision: 0.1709 - val_loss: -0.0767 - val_accuracy: 0.9906 - val_iou_seg: 0.9244 - val_mean_io_u: 0.5382 - val_recall: 0.2088 - val_iou_score: 0.0756 - val_precision: 0.1283 - lr: 6.7032e-04
# Epoch 15/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0997 - accuracy: 0.9927 - iou_seg: 0.9012 - mean_io_u: 0.5466 - recall: 0.2119 - iou_score: 0.0988 - precision: 0.1875
# Epoch 15: val_loss did not improve from -0.07674
# 114/114 [==============================] - 11s 93ms/step - loss: -0.0997 - accuracy: 0.9927 - iou_seg: 0.9012 - mean_io_u: 0.5466 - recall: 0.2119 - iou_score: 0.0988 - precision: 0.1875 - val_loss: -0.0756 - val_accuracy: 0.9914 - val_iou_seg: 0.9256 - val_mean_io_u: 0.5358 - val_recall: 0.1868 - val_iou_score: 0.0744 - val_precision: 0.1337 - lr: 6.0653e-04
# Epoch 16/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1013 - accuracy: 0.9927 - iou_seg: 0.8997 - mean_io_u: 0.5481 - recall: 0.2173 - iou_score: 0.1003 - precision: 0.1929
# Epoch 16: val_loss did not improve from -0.07674
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1013 - accuracy: 0.9927 - iou_seg: 0.8997 - mean_io_u: 0.5481 - recall: 0.2173 - iou_score: 0.1003 - precision: 0.1929 - val_loss: -0.0687 - val_accuracy: 0.9823 - val_iou_seg: 0.9319 - val_mean_io_u: 0.5335 - val_recall: 0.3019 - val_iou_score: 0.0681 - val_precision: 0.0804 - lr: 5.4881e-04
# Epoch 17/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1019 - accuracy: 0.9927 - iou_seg: 0.8990 - mean_io_u: 0.5490 - recall: 0.2191 - iou_score: 0.1010 - precision: 0.1943
# Epoch 17: val_loss improved from -0.07674 to -0.08777, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.1019 - accuracy: 0.9927 - iou_seg: 0.8990 - mean_io_u: 0.5490 - recall: 0.2191 - iou_score: 0.1010 - precision: 0.1943 - val_loss: -0.0878 - val_accuracy: 0.9924 - val_iou_seg: 0.9135 - val_mean_io_u: 0.5408 - val_recall: 0.1941 - val_iou_score: 0.0865 - val_precision: 0.1672 - lr: 4.9659e-04
# Epoch 18/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1029 - accuracy: 0.9927 - iou_seg: 0.8980 - mean_io_u: 0.5497 - recall: 0.2219 - iou_score: 0.1020 - precision: 0.1940
# Epoch 18: val_loss improved from -0.08777 to -0.08939, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.1029 - accuracy: 0.9927 - iou_seg: 0.8980 - mean_io_u: 0.5497 - recall: 0.2219 - iou_score: 0.1020 - precision: 0.1940 - val_loss: -0.0894 - val_accuracy: 0.9939 - val_iou_seg: 0.9119 - val_mean_io_u: 0.5390 - val_recall: 0.1631 - val_iou_score: 0.0881 - val_precision: 0.2149 - lr: 4.4933e-04
# Epoch 19/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1066 - accuracy: 0.9929 - iou_seg: 0.8943 - mean_io_u: 0.5529 - recall: 0.2283 - iou_score: 0.1057 - precision: 0.2037
# Epoch 19: val_loss did not improve from -0.08939
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1066 - accuracy: 0.9929 - iou_seg: 0.8943 - mean_io_u: 0.5529 - recall: 0.2283 - iou_score: 0.1057 - precision: 0.2037 - val_loss: -0.0798 - val_accuracy: 0.9881 - val_iou_seg: 0.9210 - val_mean_io_u: 0.5400 - val_recall: 0.2525 - val_iou_score: 0.0790 - val_precision: 0.1097 - lr: 4.0657e-04
# Epoch 20/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1095 - accuracy: 0.9932 - iou_seg: 0.8916 - mean_io_u: 0.5540 - recall: 0.2273 - iou_score: 0.1084 - precision: 0.2182
# Epoch 20: val_loss did not improve from -0.08939
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1095 - accuracy: 0.9932 - iou_seg: 0.8916 - mean_io_u: 0.5540 - recall: 0.2273 - iou_score: 0.1084 - precision: 0.2182 - val_loss: -0.0868 - val_accuracy: 0.9893 - val_iou_seg: 0.9140 - val_mean_io_u: 0.5422 - val_recall: 0.2521 - val_iou_score: 0.0860 - val_precision: 0.1255 - lr: 3.6788e-04
# Epoch 21/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1087 - accuracy: 0.9931 - iou_seg: 0.8923 - mean_io_u: 0.5538 - recall: 0.2255 - iou_score: 0.1077 - precision: 0.2130
# Epoch 21: val_loss did not improve from -0.08939
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1087 - accuracy: 0.9931 - iou_seg: 0.8923 - mean_io_u: 0.5538 - recall: 0.2255 - iou_score: 0.1077 - precision: 0.2130 - val_loss: -0.0663 - val_accuracy: 0.9821 - val_iou_seg: 0.9342 - val_mean_io_u: 0.5311 - val_recall: 0.2978 - val_iou_score: 0.0658 - val_precision: 0.0785 - lr: 3.3287e-04
# Epoch 22/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1103 - accuracy: 0.9932 - iou_seg: 0.8907 - mean_io_u: 0.5538 - recall: 0.2268 - iou_score: 0.1093 - precision: 0.2185
# Epoch 22: val_loss improved from -0.08939 to -0.09653, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.1103 - accuracy: 0.9932 - iou_seg: 0.8907 - mean_io_u: 0.5538 - recall: 0.2268 - iou_score: 0.1093 - precision: 0.2185 - val_loss: -0.0965 - val_accuracy: 0.9924 - val_iou_seg: 0.9044 - val_mean_io_u: 0.5457 - val_recall: 0.2095 - val_iou_score: 0.0956 - val_precision: 0.1730 - lr: 3.0119e-04
# Epoch 23/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1137 - accuracy: 0.9933 - iou_seg: 0.8873 - mean_io_u: 0.5566 - recall: 0.2343 - iou_score: 0.1127 - precision: 0.2260
# Epoch 23: val_loss did not improve from -0.09653
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1137 - accuracy: 0.9933 - iou_seg: 0.8873 - mean_io_u: 0.5566 - recall: 0.2343 - iou_score: 0.1127 - precision: 0.2260 - val_loss: -0.0899 - val_accuracy: 0.9936 - val_iou_seg: 0.9116 - val_mean_io_u: 0.5407 - val_recall: 0.1714 - val_iou_score: 0.0884 - val_precision: 0.2003 - lr: 2.7253e-04
# Epoch 24/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1159 - accuracy: 0.9934 - iou_seg: 0.8851 - mean_io_u: 0.5572 - recall: 0.2358 - iou_score: 0.1149 - precision: 0.2320
# Epoch 24: val_loss did not improve from -0.09653
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1159 - accuracy: 0.9934 - iou_seg: 0.8851 - mean_io_u: 0.5572 - recall: 0.2358 - iou_score: 0.1149 - precision: 0.2320 - val_loss: -0.0943 - val_accuracy: 0.9935 - val_iou_seg: 0.9070 - val_mean_io_u: 0.5418 - val_recall: 0.1810 - val_iou_score: 0.0930 - val_precision: 0.2015 - lr: 2.4660e-04
# Epoch 25/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1178 - accuracy: 0.9935 - iou_seg: 0.8832 - mean_io_u: 0.5565 - recall: 0.2343 - iou_score: 0.1168 - precision: 0.2366
# Epoch 25: val_loss did not improve from -0.09653
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1178 - accuracy: 0.9935 - iou_seg: 0.8832 - mean_io_u: 0.5565 - recall: 0.2343 - iou_score: 0.1168 - precision: 0.2366 - val_loss: -0.0893 - val_accuracy: 0.9898 - val_iou_seg: 0.9116 - val_mean_io_u: 0.5438 - val_recall: 0.2511 - val_iou_score: 0.0884 - val_precision: 0.1316 - lr: 2.2313e-04
# Epoch 26/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1200 - accuracy: 0.9935 - iou_seg: 0.8811 - mean_io_u: 0.5582 - recall: 0.2389 - iou_score: 0.1189 - precision: 0.2398
# Epoch 26: val_loss did not improve from -0.09653
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1200 - accuracy: 0.9935 - iou_seg: 0.8811 - mean_io_u: 0.5582 - recall: 0.2389 - iou_score: 0.1189 - precision: 0.2398 - val_loss: -0.0815 - val_accuracy: 0.9866 - val_iou_seg: 0.9193 - val_mean_io_u: 0.5409 - val_recall: 0.2870 - val_iou_score: 0.0807 - val_precision: 0.1053 - lr: 2.0190e-04
# Epoch 27/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1223 - accuracy: 0.9934 - iou_seg: 0.8788 - mean_io_u: 0.5595 - recall: 0.2451 - iou_score: 0.1212 - precision: 0.2380
# Epoch 27: val_loss did not improve from -0.09653
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1223 - accuracy: 0.9934 - iou_seg: 0.8788 - mean_io_u: 0.5595 - recall: 0.2451 - iou_score: 0.1212 - precision: 0.2380 - val_loss: -0.0858 - val_accuracy: 0.9886 - val_iou_seg: 0.9151 - val_mean_io_u: 0.5423 - val_recall: 0.2644 - val_iou_score: 0.0849 - val_precision: 0.1195 - lr: 1.8268e-04
# Epoch 28/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1231 - accuracy: 0.9936 - iou_seg: 0.8780 - mean_io_u: 0.5594 - recall: 0.2429 - iou_score: 0.1220 - precision: 0.2476
# Epoch 28: val_loss did not improve from -0.09653
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1231 - accuracy: 0.9936 - iou_seg: 0.8780 - mean_io_u: 0.5594 - recall: 0.2429 - iou_score: 0.1220 - precision: 0.2476 - val_loss: -0.0824 - val_accuracy: 0.9868 - val_iou_seg: 0.9183 - val_mean_io_u: 0.5424 - val_recall: 0.2884 - val_iou_score: 0.0817 - val_precision: 0.1082 - lr: 1.6530e-04
# Epoch 29/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1242 - accuracy: 0.9935 - iou_seg: 0.8768 - mean_io_u: 0.5599 - recall: 0.2472 - iou_score: 0.1232 - precision: 0.2455
# Epoch 29: val_loss improved from -0.09653 to -0.09684, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.1242 - accuracy: 0.9935 - iou_seg: 0.8768 - mean_io_u: 0.5599 - recall: 0.2472 - iou_score: 0.1232 - precision: 0.2455 - val_loss: -0.0968 - val_accuracy: 0.9915 - val_iou_seg: 0.9041 - val_mean_io_u: 0.5489 - val_recall: 0.2364 - val_iou_score: 0.0959 - val_precision: 0.1620 - lr: 1.4957e-04
# Epoch 30/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1280 - accuracy: 0.9936 - iou_seg: 0.8730 - mean_io_u: 0.5618 - recall: 0.2526 - iou_score: 0.1270 - precision: 0.2516
# Epoch 30: val_loss did not improve from -0.09684
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1280 - accuracy: 0.9936 - iou_seg: 0.8730 - mean_io_u: 0.5618 - recall: 0.2526 - iou_score: 0.1270 - precision: 0.2516 - val_loss: -0.0957 - val_accuracy: 0.9922 - val_iou_seg: 0.9054 - val_mean_io_u: 0.5481 - val_recall: 0.2220 - val_iou_score: 0.0946 - val_precision: 0.1735 - lr: 1.3534e-04
# Epoch 31/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1288 - accuracy: 0.9936 - iou_seg: 0.8722 - mean_io_u: 0.5618 - recall: 0.2514 - iou_score: 0.1278 - precision: 0.2561
# Epoch 31: val_loss did not improve from -0.09684
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1288 - accuracy: 0.9936 - iou_seg: 0.8722 - mean_io_u: 0.5618 - recall: 0.2514 - iou_score: 0.1278 - precision: 0.2561 - val_loss: -0.0961 - val_accuracy: 0.9920 - val_iou_seg: 0.9050 - val_mean_io_u: 0.5465 - val_recall: 0.2236 - val_iou_score: 0.0950 - val_precision: 0.1689 - lr: 1.2246e-04
# Epoch 32/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1310 - accuracy: 0.9938 - iou_seg: 0.8701 - mean_io_u: 0.5626 - recall: 0.2517 - iou_score: 0.1299 - precision: 0.2635
# Epoch 32: val_loss did not improve from -0.09684
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1310 - accuracy: 0.9938 - iou_seg: 0.8701 - mean_io_u: 0.5626 - recall: 0.2517 - iou_score: 0.1299 - precision: 0.2635 - val_loss: -0.0945 - val_accuracy: 0.9919 - val_iou_seg: 0.9065 - val_mean_io_u: 0.5457 - val_recall: 0.2225 - val_iou_score: 0.0935 - val_precision: 0.1639 - lr: 1.1080e-04
# Epoch 33/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1327 - accuracy: 0.9938 - iou_seg: 0.8684 - mean_io_u: 0.5631 - recall: 0.2540 - iou_score: 0.1316 - precision: 0.2675
# Epoch 33: val_loss improved from -0.09684 to -0.09741, saving model to Models\attunet_model_best-model.hdf5
# 114/114 [==============================] - 11s 99ms/step - loss: -0.1327 - accuracy: 0.9938 - iou_seg: 0.8684 - mean_io_u: 0.5631 - recall: 0.2540 - iou_score: 0.1316 - precision: 0.2675 - val_loss: -0.0974 - val_accuracy: 0.9928 - val_iou_seg: 0.9037 - val_mean_io_u: 0.5465 - val_recall: 0.2059 - val_iou_score: 0.0963 - val_precision: 0.1863 - lr: 1.0026e-04
# Epoch 34/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1318 - accuracy: 0.9939 - iou_seg: 0.8693 - mean_io_u: 0.5619 - recall: 0.2491 - iou_score: 0.1307 - precision: 0.2707
# Epoch 34: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1318 - accuracy: 0.9939 - iou_seg: 0.8693 - mean_io_u: 0.5619 - recall: 0.2491 - iou_score: 0.1307 - precision: 0.2707 - val_loss: -0.0958 - val_accuracy: 0.9916 - val_iou_seg: 0.9051 - val_mean_io_u: 0.5467 - val_recall: 0.2302 - val_iou_score: 0.0949 - val_precision: 0.1614 - lr: 9.0718e-05
# Epoch 35/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1333 - accuracy: 0.9937 - iou_seg: 0.8677 - mean_io_u: 0.5628 - recall: 0.2564 - iou_score: 0.1323 - precision: 0.2648
# Epoch 35: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1333 - accuracy: 0.9937 - iou_seg: 0.8677 - mean_io_u: 0.5628 - recall: 0.2564 - iou_score: 0.1323 - precision: 0.2648 - val_loss: -0.0901 - val_accuracy: 0.9935 - val_iou_seg: 0.9113 - val_mean_io_u: 0.5408 - val_recall: 0.1741 - val_iou_score: 0.0887 - val_precision: 0.1976 - lr: 8.2085e-05
# Epoch 36/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1356 - accuracy: 0.9939 - iou_seg: 0.8655 - mean_io_u: 0.5636 - recall: 0.2556 - iou_score: 0.1345 - precision: 0.2725
# Epoch 36: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1356 - accuracy: 0.9939 - iou_seg: 0.8655 - mean_io_u: 0.5636 - recall: 0.2556 - iou_score: 0.1345 - precision: 0.2725 - val_loss: -0.0949 - val_accuracy: 0.9933 - val_iou_seg: 0.9062 - val_mean_io_u: 0.5440 - val_recall: 0.1895 - val_iou_score: 0.0938 - val_precision: 0.1969 - lr: 7.4273e-05
# Epoch 37/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1372 - accuracy: 0.9939 - iou_seg: 0.8638 - mean_io_u: 0.5638 - recall: 0.2564 - iou_score: 0.1362 - precision: 0.2768
# Epoch 37: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1372 - accuracy: 0.9939 - iou_seg: 0.8638 - mean_io_u: 0.5638 - recall: 0.2564 - iou_score: 0.1362 - precision: 0.2768 - val_loss: -0.0900 - val_accuracy: 0.9934 - val_iou_seg: 0.9113 - val_mean_io_u: 0.5403 - val_recall: 0.1734 - val_iou_score: 0.0887 - val_precision: 0.1926 - lr: 6.7205e-05
# Epoch 38/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1384 - accuracy: 0.9939 - iou_seg: 0.8627 - mean_io_u: 0.5641 - recall: 0.2586 - iou_score: 0.1373 - precision: 0.2789
# Epoch 38: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1384 - accuracy: 0.9939 - iou_seg: 0.8627 - mean_io_u: 0.5641 - recall: 0.2586 - iou_score: 0.1373 - precision: 0.2789 - val_loss: -0.0888 - val_accuracy: 0.9933 - val_iou_seg: 0.9125 - val_mean_io_u: 0.5400 - val_recall: 0.1728 - val_iou_score: 0.0875 - val_precision: 0.1904 - lr: 6.0810e-05
# Epoch 39/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1391 - accuracy: 0.9940 - iou_seg: 0.8620 - mean_io_u: 0.5644 - recall: 0.2587 - iou_score: 0.1380 - precision: 0.2816
# Epoch 39: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1391 - accuracy: 0.9940 - iou_seg: 0.8620 - mean_io_u: 0.5644 - recall: 0.2587 - iou_score: 0.1380 - precision: 0.2816 - val_loss: -0.0890 - val_accuracy: 0.9933 - val_iou_seg: 0.9122 - val_mean_io_u: 0.5410 - val_recall: 0.1751 - val_iou_score: 0.0878 - val_precision: 0.1898 - lr: 5.5023e-05
# Epoch 40/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1397 - accuracy: 0.9940 - iou_seg: 0.8613 - mean_io_u: 0.5647 - recall: 0.2596 - iou_score: 0.1387 - precision: 0.2805
# Epoch 40: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1397 - accuracy: 0.9940 - iou_seg: 0.8613 - mean_io_u: 0.5647 - recall: 0.2596 - iou_score: 0.1387 - precision: 0.2805 - val_loss: -0.0936 - val_accuracy: 0.9931 - val_iou_seg: 0.9077 - val_mean_io_u: 0.5429 - val_recall: 0.1888 - val_iou_score: 0.0923 - val_precision: 0.1905 - lr: 4.9787e-05
# Epoch 41/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1409 - accuracy: 0.9940 - iou_seg: 0.8602 - mean_io_u: 0.5651 - recall: 0.2607 - iou_score: 0.1398 - precision: 0.2843
# Epoch 41: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1409 - accuracy: 0.9940 - iou_seg: 0.8602 - mean_io_u: 0.5651 - recall: 0.2607 - iou_score: 0.1398 - precision: 0.2843 - val_loss: -0.0909 - val_accuracy: 0.9933 - val_iou_seg: 0.9104 - val_mean_io_u: 0.5406 - val_recall: 0.1794 - val_iou_score: 0.0896 - val_precision: 0.1940 - lr: 4.5049e-05
# Epoch 42/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1416 - accuracy: 0.9940 - iou_seg: 0.8595 - mean_io_u: 0.5651 - recall: 0.2618 - iou_score: 0.1405 - precision: 0.2838
# Epoch 42: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1416 - accuracy: 0.9940 - iou_seg: 0.8595 - mean_io_u: 0.5651 - recall: 0.2618 - iou_score: 0.1405 - precision: 0.2838 - val_loss: -0.0881 - val_accuracy: 0.9939 - val_iou_seg: 0.9133 - val_mean_io_u: 0.5385 - val_recall: 0.1629 - val_iou_score: 0.0867 - val_precision: 0.2121 - lr: 4.0762e-05
# Epoch 43/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1424 - accuracy: 0.9940 - iou_seg: 0.8586 - mean_io_u: 0.5658 - recall: 0.2629 - iou_score: 0.1414 - precision: 0.2863
# Epoch 43: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1424 - accuracy: 0.9940 - iou_seg: 0.8586 - mean_io_u: 0.5658 - recall: 0.2629 - iou_score: 0.1414 - precision: 0.2863 - val_loss: -0.0857 - val_accuracy: 0.9939 - val_iou_seg: 0.9157 - val_mean_io_u: 0.5375 - val_recall: 0.1581 - val_iou_score: 0.0843 - val_precision: 0.2103 - lr: 3.6883e-05
# Epoch 44/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1437 - accuracy: 0.9940 - iou_seg: 0.8574 - mean_io_u: 0.5665 - recall: 0.2656 - iou_score: 0.1426 - precision: 0.2878
# Epoch 44: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1437 - accuracy: 0.9940 - iou_seg: 0.8574 - mean_io_u: 0.5665 - recall: 0.2656 - iou_score: 0.1426 - precision: 0.2878 - val_loss: -0.0816 - val_accuracy: 0.9942 - val_iou_seg: 0.9198 - val_mean_io_u: 0.5350 - val_recall: 0.1432 - val_iou_score: 0.0802 - val_precision: 0.2223 - lr: 3.3373e-05
# Epoch 45/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1441 - accuracy: 0.9940 - iou_seg: 0.8569 - mean_io_u: 0.5667 - recall: 0.2665 - iou_score: 0.1431 - precision: 0.2888
# Epoch 45: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1441 - accuracy: 0.9940 - iou_seg: 0.8569 - mean_io_u: 0.5667 - recall: 0.2665 - iou_score: 0.1431 - precision: 0.2888 - val_loss: -0.0816 - val_accuracy: 0.9943 - val_iou_seg: 0.9198 - val_mean_io_u: 0.5349 - val_recall: 0.1426 - val_iou_score: 0.0802 - val_precision: 0.2251 - lr: 3.0197e-05
# Epoch 46/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1450 - accuracy: 0.9941 - iou_seg: 0.8561 - mean_io_u: 0.5668 - recall: 0.2672 - iou_score: 0.1439 - precision: 0.2914
# Epoch 46: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1450 - accuracy: 0.9941 - iou_seg: 0.8561 - mean_io_u: 0.5668 - recall: 0.2672 - iou_score: 0.1439 - precision: 0.2914 - val_loss: -0.0792 - val_accuracy: 0.9944 - val_iou_seg: 0.9223 - val_mean_io_u: 0.5336 - val_recall: 0.1338 - val_iou_score: 0.0777 - val_precision: 0.2328 - lr: 2.7324e-05
# Epoch 47/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1456 - accuracy: 0.9941 - iou_seg: 0.8555 - mean_io_u: 0.5672 - recall: 0.2672 - iou_score: 0.1445 - precision: 0.2935
# Epoch 47: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1456 - accuracy: 0.9941 - iou_seg: 0.8555 - mean_io_u: 0.5672 - recall: 0.2672 - iou_score: 0.1445 - precision: 0.2935 - val_loss: -0.0799 - val_accuracy: 0.9944 - val_iou_seg: 0.9216 - val_mean_io_u: 0.5341 - val_recall: 0.1363 - val_iou_score: 0.0784 - val_precision: 0.2327 - lr: 2.4723e-05
# Epoch 48/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1468 - accuracy: 0.9941 - iou_seg: 0.8543 - mean_io_u: 0.5675 - recall: 0.2673 - iou_score: 0.1457 - precision: 0.2978
# Epoch 48: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1468 - accuracy: 0.9941 - iou_seg: 0.8543 - mean_io_u: 0.5675 - recall: 0.2673 - iou_score: 0.1457 - precision: 0.2978 - val_loss: -0.0797 - val_accuracy: 0.9944 - val_iou_seg: 0.9219 - val_mean_io_u: 0.5339 - val_recall: 0.1345 - val_iou_score: 0.0781 - val_precision: 0.2336 - lr: 2.2371e-05
# Epoch 49/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1475 - accuracy: 0.9942 - iou_seg: 0.8536 - mean_io_u: 0.5678 - recall: 0.2677 - iou_score: 0.1464 - precision: 0.3003
# Epoch 49: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1475 - accuracy: 0.9942 - iou_seg: 0.8536 - mean_io_u: 0.5678 - recall: 0.2677 - iou_score: 0.1464 - precision: 0.3003 - val_loss: -0.0795 - val_accuracy: 0.9944 - val_iou_seg: 0.9220 - val_mean_io_u: 0.5339 - val_recall: 0.1340 - val_iou_score: 0.0780 - val_precision: 0.2346 - lr: 2.0242e-05
# Epoch 50/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1480 - accuracy: 0.9942 - iou_seg: 0.8531 - mean_io_u: 0.5679 - recall: 0.2678 - iou_score: 0.1469 - precision: 0.3017
# Epoch 50: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1480 - accuracy: 0.9942 - iou_seg: 0.8531 - mean_io_u: 0.5679 - recall: 0.2678 - iou_score: 0.1469 - precision: 0.3017 - val_loss: -0.0810 - val_accuracy: 0.9944 - val_iou_seg: 0.9205 - val_mean_io_u: 0.5343 - val_recall: 0.1369 - val_iou_score: 0.0795 - val_precision: 0.2361 - lr: 1.8316e-05
# Epoch 51/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1487 - accuracy: 0.9942 - iou_seg: 0.8524 - mean_io_u: 0.5682 - recall: 0.2683 - iou_score: 0.1476 - precision: 0.3033
# Epoch 51: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1487 - accuracy: 0.9942 - iou_seg: 0.8524 - mean_io_u: 0.5682 - recall: 0.2683 - iou_score: 0.1476 - precision: 0.3033 - val_loss: -0.0806 - val_accuracy: 0.9945 - val_iou_seg: 0.9209 - val_mean_io_u: 0.5343 - val_recall: 0.1359 - val_iou_score: 0.0791 - val_precision: 0.2366 - lr: 1.6573e-05
# Epoch 52/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1493 - accuracy: 0.9942 - iou_seg: 0.8519 - mean_io_u: 0.5684 - recall: 0.2687 - iou_score: 0.1481 - precision: 0.3048
# Epoch 52: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1493 - accuracy: 0.9942 - iou_seg: 0.8519 - mean_io_u: 0.5684 - recall: 0.2687 - iou_score: 0.1481 - precision: 0.3048 - val_loss: -0.0809 - val_accuracy: 0.9945 - val_iou_seg: 0.9206 - val_mean_io_u: 0.5344 - val_recall: 0.1363 - val_iou_score: 0.0794 - val_precision: 0.2377 - lr: 1.4996e-05
# Epoch 53/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1498 - accuracy: 0.9942 - iou_seg: 0.8513 - mean_io_u: 0.5687 - recall: 0.2693 - iou_score: 0.1487 - precision: 0.3063
# Epoch 53: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1498 - accuracy: 0.9942 - iou_seg: 0.8513 - mean_io_u: 0.5687 - recall: 0.2693 - iou_score: 0.1487 - precision: 0.3063 - val_loss: -0.0813 - val_accuracy: 0.9944 - val_iou_seg: 0.9203 - val_mean_io_u: 0.5347 - val_recall: 0.1374 - val_iou_score: 0.0797 - val_precision: 0.2374 - lr: 1.3569e-05
# Epoch 54/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1502 - accuracy: 0.9943 - iou_seg: 0.8509 - mean_io_u: 0.5688 - recall: 0.2699 - iou_score: 0.1491 - precision: 0.3076
# Epoch 54: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1502 - accuracy: 0.9943 - iou_seg: 0.8509 - mean_io_u: 0.5688 - recall: 0.2699 - iou_score: 0.1491 - precision: 0.3076 - val_loss: -0.0823 - val_accuracy: 0.9944 - val_iou_seg: 0.9192 - val_mean_io_u: 0.5352 - val_recall: 0.1400 - val_iou_score: 0.0808 - val_precision: 0.2390 - lr: 1.2277e-05
# Epoch 55/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1506 - accuracy: 0.9943 - iou_seg: 0.8505 - mean_io_u: 0.5691 - recall: 0.2704 - iou_score: 0.1495 - precision: 0.3085
# Epoch 55: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1506 - accuracy: 0.9943 - iou_seg: 0.8505 - mean_io_u: 0.5691 - recall: 0.2704 - iou_score: 0.1495 - precision: 0.3085 - val_loss: -0.0827 - val_accuracy: 0.9944 - val_iou_seg: 0.9188 - val_mean_io_u: 0.5355 - val_recall: 0.1413 - val_iou_score: 0.0812 - val_precision: 0.2375 - lr: 1.1109e-05
# Epoch 56/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1510 - accuracy: 0.9943 - iou_seg: 0.8501 - mean_io_u: 0.5692 - recall: 0.2708 - iou_score: 0.1499 - precision: 0.3097
# Epoch 56: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1510 - accuracy: 0.9943 - iou_seg: 0.8501 - mean_io_u: 0.5692 - recall: 0.2708 - iou_score: 0.1499 - precision: 0.3097 - val_loss: -0.0828 - val_accuracy: 0.9944 - val_iou_seg: 0.9187 - val_mean_io_u: 0.5358 - val_recall: 0.1421 - val_iou_score: 0.0813 - val_precision: 0.2365 - lr: 1.0052e-05
# Epoch 57/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1514 - accuracy: 0.9943 - iou_seg: 0.8497 - mean_io_u: 0.5693 - recall: 0.2714 - iou_score: 0.1503 - precision: 0.3105
# Epoch 57: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1514 - accuracy: 0.9943 - iou_seg: 0.8497 - mean_io_u: 0.5693 - recall: 0.2714 - iou_score: 0.1503 - precision: 0.3105 - val_loss: -0.0832 - val_accuracy: 0.9944 - val_iou_seg: 0.9183 - val_mean_io_u: 0.5360 - val_recall: 0.1432 - val_iou_score: 0.0817 - val_precision: 0.2367 - lr: 9.0953e-06
# Epoch 58/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1517 - accuracy: 0.9943 - iou_seg: 0.8495 - mean_io_u: 0.5694 - recall: 0.2718 - iou_score: 0.1505 - precision: 0.3114
# Epoch 58: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1517 - accuracy: 0.9943 - iou_seg: 0.8495 - mean_io_u: 0.5694 - recall: 0.2718 - iou_score: 0.1505 - precision: 0.3114 - val_loss: -0.0834 - val_accuracy: 0.9944 - val_iou_seg: 0.9181 - val_mean_io_u: 0.5363 - val_recall: 0.1437 - val_iou_score: 0.0819 - val_precision: 0.2369 - lr: 8.2297e-06
# Epoch 59/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1519 - accuracy: 0.9943 - iou_seg: 0.8492 - mean_io_u: 0.5695 - recall: 0.2721 - iou_score: 0.1508 - precision: 0.3121
# Epoch 59: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1519 - accuracy: 0.9943 - iou_seg: 0.8492 - mean_io_u: 0.5695 - recall: 0.2721 - iou_score: 0.1508 - precision: 0.3121 - val_loss: -0.0836 - val_accuracy: 0.9944 - val_iou_seg: 0.9179 - val_mean_io_u: 0.5364 - val_recall: 0.1444 - val_iou_score: 0.0821 - val_precision: 0.2370 - lr: 7.4466e-06
# Epoch 60/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1522 - accuracy: 0.9943 - iou_seg: 0.8490 - mean_io_u: 0.5696 - recall: 0.2723 - iou_score: 0.1510 - precision: 0.3126
# Epoch 60: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1522 - accuracy: 0.9943 - iou_seg: 0.8490 - mean_io_u: 0.5696 - recall: 0.2723 - iou_score: 0.1510 - precision: 0.3126 - val_loss: -0.0837 - val_accuracy: 0.9944 - val_iou_seg: 0.9178 - val_mean_io_u: 0.5368 - val_recall: 0.1447 - val_iou_score: 0.0822 - val_precision: 0.2370 - lr: 6.7379e-06
# Epoch 61/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1524 - accuracy: 0.9943 - iou_seg: 0.8488 - mean_io_u: 0.5697 - recall: 0.2726 - iou_score: 0.1512 - precision: 0.3131
# Epoch 61: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1524 - accuracy: 0.9943 - iou_seg: 0.8488 - mean_io_u: 0.5697 - recall: 0.2726 - iou_score: 0.1512 - precision: 0.3131 - val_loss: -0.0838 - val_accuracy: 0.9944 - val_iou_seg: 0.9176 - val_mean_io_u: 0.5369 - val_recall: 0.1448 - val_iou_score: 0.0824 - val_precision: 0.2369 - lr: 6.0967e-06
# Epoch 62/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1525 - accuracy: 0.9943 - iou_seg: 0.8486 - mean_io_u: 0.5697 - recall: 0.2728 - iou_score: 0.1514 - precision: 0.3137
# Epoch 62: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1525 - accuracy: 0.9943 - iou_seg: 0.8486 - mean_io_u: 0.5697 - recall: 0.2728 - iou_score: 0.1514 - precision: 0.3137 - val_loss: -0.0841 - val_accuracy: 0.9944 - val_iou_seg: 0.9174 - val_mean_io_u: 0.5371 - val_recall: 0.1456 - val_iou_score: 0.0826 - val_precision: 0.2370 - lr: 5.5165e-06
# Epoch 63/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1527 - accuracy: 0.9943 - iou_seg: 0.8484 - mean_io_u: 0.5698 - recall: 0.2731 - iou_score: 0.1516 - precision: 0.3142
# Epoch 63: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1527 - accuracy: 0.9943 - iou_seg: 0.8484 - mean_io_u: 0.5698 - recall: 0.2731 - iou_score: 0.1516 - precision: 0.3142 - val_loss: -0.0841 - val_accuracy: 0.9944 - val_iou_seg: 0.9174 - val_mean_io_u: 0.5371 - val_recall: 0.1454 - val_iou_score: 0.0826 - val_precision: 0.2372 - lr: 4.9916e-06
# Epoch 64/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1528 - accuracy: 0.9943 - iou_seg: 0.8483 - mean_io_u: 0.5698 - recall: 0.2732 - iou_score: 0.1517 - precision: 0.3144
# Epoch 64: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1528 - accuracy: 0.9943 - iou_seg: 0.8483 - mean_io_u: 0.5698 - recall: 0.2732 - iou_score: 0.1517 - precision: 0.3144 - val_loss: -0.0844 - val_accuracy: 0.9944 - val_iou_seg: 0.9171 - val_mean_io_u: 0.5372 - val_recall: 0.1463 - val_iou_score: 0.0829 - val_precision: 0.2375 - lr: 4.5166e-06
# Epoch 65/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1530 - accuracy: 0.9943 - iou_seg: 0.8481 - mean_io_u: 0.5699 - recall: 0.2733 - iou_score: 0.1519 - precision: 0.3148
# Epoch 65: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1530 - accuracy: 0.9943 - iou_seg: 0.8481 - mean_io_u: 0.5699 - recall: 0.2733 - iou_score: 0.1519 - precision: 0.3148 - val_loss: -0.0843 - val_accuracy: 0.9944 - val_iou_seg: 0.9171 - val_mean_io_u: 0.5372 - val_recall: 0.1463 - val_iou_score: 0.0829 - val_precision: 0.2378 - lr: 4.0868e-06
# Epoch 66/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1531 - accuracy: 0.9943 - iou_seg: 0.8480 - mean_io_u: 0.5700 - recall: 0.2734 - iou_score: 0.1520 - precision: 0.3150
# Epoch 66: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1531 - accuracy: 0.9943 - iou_seg: 0.8480 - mean_io_u: 0.5700 - recall: 0.2734 - iou_score: 0.1520 - precision: 0.3150 - val_loss: -0.0845 - val_accuracy: 0.9944 - val_iou_seg: 0.9170 - val_mean_io_u: 0.5373 - val_recall: 0.1466 - val_iou_score: 0.0830 - val_precision: 0.2378 - lr: 3.6979e-06
# Epoch 67/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1532 - accuracy: 0.9943 - iou_seg: 0.8479 - mean_io_u: 0.5700 - recall: 0.2736 - iou_score: 0.1521 - precision: 0.3154
# Epoch 67: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1532 - accuracy: 0.9943 - iou_seg: 0.8479 - mean_io_u: 0.5700 - recall: 0.2736 - iou_score: 0.1521 - precision: 0.3154 - val_loss: -0.0844 - val_accuracy: 0.9944 - val_iou_seg: 0.9171 - val_mean_io_u: 0.5373 - val_recall: 0.1464 - val_iou_score: 0.0829 - val_precision: 0.2381 - lr: 3.3460e-06
# Epoch 68/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1533 - accuracy: 0.9943 - iou_seg: 0.8478 - mean_io_u: 0.5700 - recall: 0.2738 - iou_score: 0.1522 - precision: 0.3155
# Epoch 68: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1533 - accuracy: 0.9943 - iou_seg: 0.8478 - mean_io_u: 0.5700 - recall: 0.2738 - iou_score: 0.1522 - precision: 0.3155 - val_loss: -0.0845 - val_accuracy: 0.9944 - val_iou_seg: 0.9170 - val_mean_io_u: 0.5374 - val_recall: 0.1467 - val_iou_score: 0.0830 - val_precision: 0.2382 - lr: 3.0275e-06
# Epoch 69/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1534 - accuracy: 0.9943 - iou_seg: 0.8477 - mean_io_u: 0.5700 - recall: 0.2740 - iou_score: 0.1523 - precision: 0.3158
# Epoch 69: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1534 - accuracy: 0.9943 - iou_seg: 0.8477 - mean_io_u: 0.5700 - recall: 0.2740 - iou_score: 0.1523 - precision: 0.3158 - val_loss: -0.0845 - val_accuracy: 0.9944 - val_iou_seg: 0.9170 - val_mean_io_u: 0.5374 - val_recall: 0.1466 - val_iou_score: 0.0830 - val_precision: 0.2384 - lr: 2.7394e-06
# Epoch 70/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1535 - accuracy: 0.9943 - iou_seg: 0.8476 - mean_io_u: 0.5701 - recall: 0.2741 - iou_score: 0.1524 - precision: 0.3159
# Epoch 70: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1535 - accuracy: 0.9943 - iou_seg: 0.8476 - mean_io_u: 0.5701 - recall: 0.2741 - iou_score: 0.1524 - precision: 0.3159 - val_loss: -0.0845 - val_accuracy: 0.9944 - val_iou_seg: 0.9170 - val_mean_io_u: 0.5375 - val_recall: 0.1467 - val_iou_score: 0.0830 - val_precision: 0.2383 - lr: 2.4787e-06
# Epoch 71/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1536 - accuracy: 0.9943 - iou_seg: 0.8476 - mean_io_u: 0.5701 - recall: 0.2742 - iou_score: 0.1524 - precision: 0.3161
# Epoch 71: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1536 - accuracy: 0.9943 - iou_seg: 0.8476 - mean_io_u: 0.5701 - recall: 0.2742 - iou_score: 0.1524 - precision: 0.3161 - val_loss: -0.0845 - val_accuracy: 0.9944 - val_iou_seg: 0.9169 - val_mean_io_u: 0.5375 - val_recall: 0.1465 - val_iou_score: 0.0831 - val_precision: 0.2383 - lr: 2.2429e-06
# Epoch 72/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1536 - accuracy: 0.9943 - iou_seg: 0.8475 - mean_io_u: 0.5701 - recall: 0.2742 - iou_score: 0.1525 - precision: 0.3162
# Epoch 72: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1536 - accuracy: 0.9943 - iou_seg: 0.8475 - mean_io_u: 0.5701 - recall: 0.2742 - iou_score: 0.1525 - precision: 0.3162 - val_loss: -0.0846 - val_accuracy: 0.9944 - val_iou_seg: 0.9169 - val_mean_io_u: 0.5376 - val_recall: 0.1466 - val_iou_score: 0.0831 - val_precision: 0.2382 - lr: 2.0294e-06
# Epoch 73/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1537 - accuracy: 0.9943 - iou_seg: 0.8474 - mean_io_u: 0.5701 - recall: 0.2742 - iou_score: 0.1526 - precision: 0.3163
# Epoch 73: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1537 - accuracy: 0.9943 - iou_seg: 0.8474 - mean_io_u: 0.5701 - recall: 0.2742 - iou_score: 0.1526 - precision: 0.3163 - val_loss: -0.0846 - val_accuracy: 0.9944 - val_iou_seg: 0.9169 - val_mean_io_u: 0.5376 - val_recall: 0.1466 - val_iou_score: 0.0831 - val_precision: 0.2383 - lr: 1.8363e-06
# Epoch 74/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1537 - accuracy: 0.9943 - iou_seg: 0.8474 - mean_io_u: 0.5701 - recall: 0.2743 - iou_score: 0.1526 - precision: 0.3164
# Epoch 74: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1537 - accuracy: 0.9943 - iou_seg: 0.8474 - mean_io_u: 0.5701 - recall: 0.2743 - iou_score: 0.1526 - precision: 0.3164 - val_loss: -0.0846 - val_accuracy: 0.9944 - val_iou_seg: 0.9169 - val_mean_io_u: 0.5376 - val_recall: 0.1466 - val_iou_score: 0.0831 - val_precision: 0.2382 - lr: 1.6616e-06
# Epoch 75/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1538 - accuracy: 0.9943 - iou_seg: 0.8473 - mean_io_u: 0.5702 - recall: 0.2744 - iou_score: 0.1527 - precision: 0.3166
# Epoch 75: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1538 - accuracy: 0.9943 - iou_seg: 0.8473 - mean_io_u: 0.5702 - recall: 0.2744 - iou_score: 0.1527 - precision: 0.3166 - val_loss: -0.0846 - val_accuracy: 0.9944 - val_iou_seg: 0.9169 - val_mean_io_u: 0.5376 - val_recall: 0.1466 - val_iou_score: 0.0831 - val_precision: 0.2382 - lr: 1.5034e-06
# Epoch 76/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1538 - accuracy: 0.9943 - iou_seg: 0.8473 - mean_io_u: 0.5702 - recall: 0.2745 - iou_score: 0.1527 - precision: 0.3167
# Epoch 76: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1538 - accuracy: 0.9943 - iou_seg: 0.8473 - mean_io_u: 0.5702 - recall: 0.2745 - iou_score: 0.1527 - precision: 0.3167 - val_loss: -0.0847 - val_accuracy: 0.9944 - val_iou_seg: 0.9168 - val_mean_io_u: 0.5376 - val_recall: 0.1466 - val_iou_score: 0.0832 - val_precision: 0.2384 - lr: 1.3604e-06
# Epoch 77/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1539 - accuracy: 0.9943 - iou_seg: 0.8473 - mean_io_u: 0.5702 - recall: 0.2746 - iou_score: 0.1527 - precision: 0.3168
# Epoch 77: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1539 - accuracy: 0.9943 - iou_seg: 0.8473 - mean_io_u: 0.5702 - recall: 0.2746 - iou_score: 0.1527 - precision: 0.3168 - val_loss: -0.0847 - val_accuracy: 0.9944 - val_iou_seg: 0.9168 - val_mean_io_u: 0.5376 - val_recall: 0.1466 - val_iou_score: 0.0832 - val_precision: 0.2384 - lr: 1.2309e-06
# Epoch 78/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1539 - accuracy: 0.9943 - iou_seg: 0.8472 - mean_io_u: 0.5702 - recall: 0.2746 - iou_score: 0.1528 - precision: 0.3170
# Epoch 78: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1539 - accuracy: 0.9943 - iou_seg: 0.8472 - mean_io_u: 0.5702 - recall: 0.2746 - iou_score: 0.1528 - precision: 0.3170 - val_loss: -0.0847 - val_accuracy: 0.9944 - val_iou_seg: 0.9168 - val_mean_io_u: 0.5376 - val_recall: 0.1467 - val_iou_score: 0.0832 - val_precision: 0.2384 - lr: 1.1138e-06
# Epoch 79/150
# ...
# Epoch 125/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 125: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 1.0130e-08
# Epoch 126/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 126: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 9.1660e-09
# Epoch 127/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 127: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 8.2938e-09
# Epoch 128/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 128: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 7.5045e-09
# Epoch 129/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 129: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 6.7904e-09
# Epoch 130/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 130: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 6.1442e-09
# Epoch 131/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 131: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 5.5595e-09
# Epoch 132/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 132: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 5.0304e-09
# Epoch 133/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 133: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 4.5517e-09
# Epoch 134/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 134: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 4.1186e-09
# Epoch 135/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 135: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 3.7266e-09
# Epoch 136/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 136: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 3.3720e-09
# Epoch 137/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 137: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 3.0511e-09
# Epoch 138/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 138: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 2.7608e-09
# Epoch 139/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 139: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 2.4980e-09
# Epoch 140/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 140: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 2.2603e-09
# Epoch 141/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 141: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 2.0452e-09
# Epoch 142/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 142: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 1.8506e-09
# Epoch 143/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 143: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 1.6745e-09
# Epoch 144/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 144: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 1.5151e-09
# Epoch 145/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 145: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 1.3709e-09
# Epoch 146/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 146: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 1.2405e-09
# Epoch 147/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 147: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 1.1224e-09
# Epoch 148/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 148: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 1.0156e-09
# Epoch 149/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 149: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 9.1897e-10
# Epoch 150/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177
# Epoch 150: val_loss did not improve from -0.09741
# 114/114 [==============================] - 11s 93ms/step - loss: -0.1542 - accuracy: 0.9943 - iou_seg: 0.8469 - mean_io_u: 0.5703 - recall: 0.2751 - iou_score: 0.1531 - precision: 0.3177 - val_loss: -0.0848 - val_accuracy: 0.9944 - val_iou_seg: 0.9167 - val_mean_io_u: 0.5378 - val_recall: 0.1470 - val_iou_score: 0.0833 - val_precision: 0.2386 - lr: 8.3152e-10
# attunet_model execution time is:  0:26:56.764954

# %%
predictions=model.predict(X_test)
predictions.shape
# Out:
# 13/13 [==============================] - 10s 66ms/step
# (391, 128, 128, 1)

# %%
predictions=(predictions>0.5).astype(np.int8)

# %%
def compute_iou(predictions, masks):
    intersection = np.logical_and(predictions, masks)
    union = np.logical_or(predictions, masks)
    iou = np.sum(intersection) / np.sum(union)
    return iou

def compute_mean_iou(predictions_list, masks_list):
    num_samples = len(predictions_list)
    total_iou = 0.0

    for i in range(num_samples):
        predictions = predictions_list[i]
        masks = masks_list[i]

        iou = compute_iou(predictions, masks)
        total_iou += iou

    mean_iou = total_iou / num_samples
    return mean_iou

# %%
compute_iou(predictions, y_test)
# Out:
# 0.1000648637860493

# %%
def plot_random_comparison(X_test, y_test, predictions):
    """Plot comparison between a randomly selected test image, its ground truth, and predicted segmentation mask."""
    # Generate a random index
    index = np.random.randint(0, len(X_test))
    print(str(index)+"\n")
    iou=compute_iou(y_test[index], predictions[index])
    
    plt.figure(figsize=(12, 4))
    
    # Plot the test image
    plt.subplot(1, 3, 1)
    plt.imshow(X_test[index,:,:,0:3])
    plt.title('Test Image')
    plt.axis('off')
    
    # Plot the ground truth mask
    plt.subplot(1, 3, 2)
    plt.imshow(y_test[index].squeeze(), cmap='gray')  # Use .squeeze() in case your mask has an extra dimension
    plt.title('Ground Truth Mask')
    plt.axis('off')
    
    # Plot the predicted mask
    plt.subplot(1, 3, 3)
    plt.imshow(predictions[index].squeeze(), cmap='gray')  # Use .squeeze() in case your prediction has an extra dimension
    plt.title(f'Predicted Mask {iou}')
    plt.axis('off')
    plt.show()

# %%
plot_random_comparison(X_test, y_test, predictions)
# Out:
# 134
