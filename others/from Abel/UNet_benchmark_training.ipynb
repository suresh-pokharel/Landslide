# %%
import os
from natsort import natsorted
import random
import tifffile as tiff
import cv2
from matplotlib import pyplot as plt
import numpy as np

import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
img_dir = "new_dataset/images/"
mask_dir = "new_dataset/masks/"

#img_dir = "new_dataset_Italy/images/"
#mask_dir = "new_dataset_Italy/masks/"

img_list = os.listdir(img_dir)
img_list=natsorted(img_list)

msk_list = os.listdir(mask_dir)
msk_list=natsorted(msk_list)

num_images = len(os.listdir(img_dir))

# %%
def reading_images(root_path, files):
    images=[]
    for file in files:
        img=tiff.imread(root_path+file)
        #print(img[:10,0])
        images.append(img)
    return images

# %%
masks=reading_images(mask_dir, msk_list)
masks_ar=np.array(masks)
masks_ar=np.expand_dims(masks_ar, axis=-1)

imgs=reading_images(img_dir, img_list)
imgs_ar=np.array(imgs)

# %%
imgs_ar.shape, masks_ar.shape
# Out:
# ((1303, 128, 128, 14), (1303, 128, 128, 1))

# %%
def min_max_scaler_image(image):
    normalized_image = np.zeros_like(image)
    for i in range(image.shape[2]):
        max_value=np.max(image[:,:,i])
        min_value=np.min(image[:,:,i])
        normalized_image[:,:,i] = image[:,:,i]/ max_value
        #normalized_image[:,:,i] = normalized_image[:,:,i] + 0.5
        #normalized_image[:,:,i] = np.clip(normalized_image[:,:,i], 0, 1)
    return normalized_image

# %%
def scale_normalize_image(image, means, stds):
    normalized_image = np.zeros_like(image)
    for i in range(image.shape[2]):
        normalized_image[:,:,i] = (image[:,:,i] - means[i]) / (2 * stds[i])
        normalized_image[:,:,i] = normalized_image[:,:,i] + 0.5
        normalized_image[:,:,i] = np.clip(normalized_image[:,:,i], 0, 1)
    return normalized_image

# %%
means=[]
stds=[]
for i in range(0,14):
    print(np.mean(imgs_ar[:,:,:,i]), np.max(imgs_ar[:,:,:,i]), np.min(imgs_ar[:,:,:,i]), np.std(imgs_ar[:,:,:,i]))
    means.append(np.mean(imgs_ar[:,:,:,i]))
    stds.append(np.std(imgs_ar[:,:,:,i]))
# Out:
# 1052.0874 1905.0 0.0 275.63873
# 786.344 3638.0 0.0 219.11479
# 675.8054 3652.0 0.0 205.79753
# 468.578 4746.0 0.0 216.42885
# 759.43427 3624.0 0.0 276.08264
# 1726.8557 4256.0 0.0 584.2288
# 2134.1873 5584.0 0.0 735.80164
# 2175.0952 6059.0 0.0 799.70184
# 994.03235 2989.0 0.0 413.959
# 14.251601 223.0 0.0 12.503192
# 1372.7716 5433.0 0.0 603.5555
# 668.4369 10459.0 0.0 394.17944
# 18.941736 77.98855 0.0 11.342175
# 572.7976 2431.891 0.0 425.39337

# %%
imgs_norm=[]
for img in imgs_ar:
#    img_std=min_max_scaler_image(img)
    img_std=scale_normalize_image(img, means, stds)
    imgs_norm.append(img_std)  
imgs_norm=np.array(imgs_norm)

imgs_ar=imgs_norm

# %%
n_random_samples  = 6
n_bands = 14  # Now we have 14 bands in total

#fig, axs = plt.subplots(n_samples_to_plot, 12, figsize=(20, 16))  # 1 RGB composite + 11 individual bands + 1 mask

# Generate random sample indices
random_indices = np.random.choice(np.arange(imgs_ar.shape[0]), size=n_random_samples, replace=False)

# Plotting the random samples
fig, axs = plt.subplots(n_random_samples, 12, figsize=(20, 16))  # Layout configuration

for i, sample_idx in enumerate(random_indices):
    # Create an RGB composite image from the first 3 bands for the selected sample
    rgb_image = imgs_ar[sample_idx, :, :, :3]
    rgb_image /= rgb_image.max()  # Normalizing to [0, 1] for displaying as RGB
    axs[i, 0].imshow(rgb_image)
    axs[i, 0].axis('off')  # Hide axis
    if i == 0:
        axs[i, 0].set_title('RGB Composite', size='large')
    
    for band_idx in range(3, n_bands):  # Starting from the 4th band
        axs[i, band_idx-2].imshow(imgs_ar[sample_idx, :, :, band_idx])#, cmap='gray')
        axs[i, band_idx-2].axis('off')  # Hide axis
        if i == 0:
            axs[0, band_idx-2].set_title(f'Band {band_idx+1}', size='large')

    # Plotting the segmentation mask for the selected sample
    axs[i, 11].imshow(masks_ar[sample_idx, :, :], cmap='gray')
    axs[i, 11].axis('off')
    if i == 0:
        axs[0, 11].set_title('Segmentation Mask', size='large')

plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs_ar, masks_ar, test_size=0.3, random_state=42)

# %%
np.unique(y_test), np.unique(y_train)
# Out:
# (array([0, 1], dtype=uint8), array([0, 1], dtype=uint8))

# %%
from keras_unet_collection import models
from keras_unet_collection import losses
import segmentation_models as sm
from tensorflow.python.framework import ops
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow import keras
from datetime import datetime
# Out:
# Segmentation Models: using `keras` framework.

# %%
model = models.unet_2d((X_train.shape[-3], X_train.shape[-2], X_train.shape[-1]), [64, 128, 256, 512, 1024], n_labels=1,
                      stack_num_down=2, stack_num_up=2,
                      activation='ReLU', output_activation='Sigmoid', 
                      batch_norm=True, pool='max', unpool='nearest', name='unet')

# %%
model.summary()
# Out:
# Model: "unet_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 4)]
#
#  unet_down0_0 (Conv2D)          (None, 128, 128, 64  8064        ['input_1[0][0]']
#                                 )
#
#  unet_down0_0_bn (BatchNormaliz  (None, 128, 128, 64  256        ['unet_down0_0[0][0]']
#  ation)                         )
#
#  unet_down0_0_activation (ReLU)  (None, 128, 128, 64  0          ['unet_down0_0_bn[0][0]']
#                                 )
#
#  unet_down0_1 (Conv2D)          (None, 128, 128, 64  36864       ['unet_down0_0_activation[0][0]']
#                                 )
#
#  unet_down0_1_bn (BatchNormaliz  (None, 128, 128, 64  256        ['unet_down0_1[0][0]']
#  ation)                         )
#
#  unet_down0_1_activation (ReLU)  (None, 128, 128, 64  0          ['unet_down0_1_bn[0][0]']
#                                 )
#
#  unet_down1_encode_maxpool (Max  (None, 64, 64, 64)  0           ['unet_down0_1_activation[0][0]']
#  Pooling2D)
#
#  unet_down1_conv_0 (Conv2D)     (None, 64, 64, 128)  73728       ['unet_down1_encode_maxpool[0][0]
#                                                                  ']
#
#  unet_down1_conv_0_bn (BatchNor  (None, 64, 64, 128)  512        ['unet_down1_conv_0[0][0]']
#  malization)
#
#  unet_down1_conv_0_activation (  (None, 64, 64, 128)  0          ['unet_down1_conv_0_bn[0][0]']
#  ReLU)
#
#  unet_down1_conv_1 (Conv2D)     (None, 64, 64, 128)  147456      ['unet_down1_conv_0_activation[0]
#                                                                  [0]']
#
#  unet_down1_conv_1_bn (BatchNor  (None, 64, 64, 128)  512        ['unet_down1_conv_1[0][0]']
#  malization)
#
#  unet_down1_conv_1_activation (  (None, 64, 64, 128)  0          ['unet_down1_conv_1_bn[0][0]']
#  ReLU)
#
#  unet_down2_encode_maxpool (Max  (None, 32, 32, 128)  0          ['unet_down1_conv_1_activation[0]
#  Pooling2D)                                                      [0]']
#
#  unet_down2_conv_0 (Conv2D)     (None, 32, 32, 256)  294912      ['unet_down2_encode_maxpool[0][0]
#                                                                  ']
#
#  unet_down2_conv_0_bn (BatchNor  (None, 32, 32, 256)  1024       ['unet_down2_conv_0[0][0]']
#  malization)
#
#  unet_down2_conv_0_activation (  (None, 32, 32, 256)  0          ['unet_down2_conv_0_bn[0][0]']
#  ReLU)
#
#  unet_down2_conv_1 (Conv2D)     (None, 32, 32, 256)  589824      ['unet_down2_conv_0_activation[0]
#                                                                  [0]']
#
#  unet_down2_conv_1_bn (BatchNor  (None, 32, 32, 256)  1024       ['unet_down2_conv_1[0][0]']
#  malization)
#
#  unet_down2_conv_1_activation (  (None, 32, 32, 256)  0          ['unet_down2_conv_1_bn[0][0]']
#  ReLU)
#
#  unet_down3_encode_maxpool (Max  (None, 16, 16, 256)  0          ['unet_down2_conv_1_activation[0]
#  Pooling2D)                                                      [0]']
#
#  unet_down3_conv_0 (Conv2D)     (None, 16, 16, 512)  1179648     ['unet_down3_encode_maxpool[0][0]
#                                                                  ']
#
#  unet_down3_conv_0_bn (BatchNor  (None, 16, 16, 512)  2048       ['unet_down3_conv_0[0][0]']
#  malization)
#
#  unet_down3_conv_0_activation (  (None, 16, 16, 512)  0          ['unet_down3_conv_0_bn[0][0]']
#  ReLU)
#
#  unet_down3_conv_1 (Conv2D)     (None, 16, 16, 512)  2359296     ['unet_down3_conv_0_activation[0]
#                                                                  [0]']
#
#  unet_down3_conv_1_bn (BatchNor  (None, 16, 16, 512)  2048       ['unet_down3_conv_1[0][0]']
#  malization)
#
#  unet_down3_conv_1_activation (  (None, 16, 16, 512)  0          ['unet_down3_conv_1_bn[0][0]']
#  ReLU)
#
#  unet_down4_encode_maxpool (Max  (None, 8, 8, 512)   0           ['unet_down3_conv_1_activation[0]
#  Pooling2D)                                                      [0]']
#
#  unet_down4_conv_0 (Conv2D)     (None, 8, 8, 1024)   4718592     ['unet_down4_encode_maxpool[0][0]
#                                                                  ']
#
#  unet_down4_conv_0_bn (BatchNor  (None, 8, 8, 1024)  4096        ['unet_down4_conv_0[0][0]']
#  malization)
#
#  unet_down4_conv_0_activation (  (None, 8, 8, 1024)  0           ['unet_down4_conv_0_bn[0][0]']
#  ReLU)
#
#  unet_down4_conv_1 (Conv2D)     (None, 8, 8, 1024)   9437184     ['unet_down4_conv_0_activation[0]
#                                                                  [0]']
#
#  unet_down4_conv_1_bn (BatchNor  (None, 8, 8, 1024)  4096        ['unet_down4_conv_1[0][0]']
#  malization)
#
#  unet_down4_conv_1_activation (  (None, 8, 8, 1024)  0           ['unet_down4_conv_1_bn[0][0]']
#  ReLU)
#
#  unet_up0_decode_unpool (UpSamp  (None, 16, 16, 1024  0          ['unet_down4_conv_1_activation[0]
#  ling2D)                        )                                [0]']
#
#  unet_up0_conv_before_concat_0   (None, 16, 16, 512)  4718592    ['unet_up0_decode_unpool[0][0]']
#  (Conv2D)
#
#  unet_up0_conv_before_concat_0_  (None, 16, 16, 512)  2048       ['unet_up0_conv_before_concat_0[0
#  bn (BatchNormalization)                                         ][0]']
#
#  unet_up0_conv_before_concat_0_  (None, 16, 16, 512)  0          ['unet_up0_conv_before_concat_0_b
#  activation (ReLU)                                               n[0][0]']
#
#  unet_up0_concat (Concatenate)  (None, 16, 16, 1024  0           ['unet_up0_conv_before_concat_0_a
#                                 )                                ctivation[0][0]',
#                                                                   'unet_down3_conv_1_activation[0]
#                                                                  [0]']
#
#  unet_up0_conv_after_concat_0 (  (None, 16, 16, 512)  4718592    ['unet_up0_concat[0][0]']
#  Conv2D)
#
#  unet_up0_conv_after_concat_0_b  (None, 16, 16, 512)  2048       ['unet_up0_conv_after_concat_0[0]
#  n (BatchNormalization)                                          [0]']
#
#  unet_up0_conv_after_concat_0_a  (None, 16, 16, 512)  0          ['unet_up0_conv_after_concat_0_bn
#  ctivation (ReLU)                                                [0][0]']
#
#  unet_up0_conv_after_concat_1 (  (None, 16, 16, 512)  2359296    ['unet_up0_conv_after_concat_0_ac
#  Conv2D)                                                         tivation[0][0]']
#
#  unet_up0_conv_after_concat_1_b  (None, 16, 16, 512)  2048       ['unet_up0_conv_after_concat_1[0]
#  n (BatchNormalization)                                          [0]']
#
#  unet_up0_conv_after_concat_1_a  (None, 16, 16, 512)  0          ['unet_up0_conv_after_concat_1_bn
#  ctivation (ReLU)                                                [0][0]']
#
#  unet_up1_decode_unpool (UpSamp  (None, 32, 32, 512)  0          ['unet_up0_conv_after_concat_1_ac
#  ling2D)                                                         tivation[0][0]']
#
#  unet_up1_conv_before_concat_0   (None, 32, 32, 256)  1179648    ['unet_up1_decode_unpool[0][0]']
#  (Conv2D)
#
#  unet_up1_conv_before_concat_0_  (None, 32, 32, 256)  1024       ['unet_up1_conv_before_concat_0[0
#  bn (BatchNormalization)                                         ][0]']
#
#  unet_up1_conv_before_concat_0_  (None, 32, 32, 256)  0          ['unet_up1_conv_before_concat_0_b
#  activation (ReLU)                                               n[0][0]']
#
#  unet_up1_concat (Concatenate)  (None, 32, 32, 512)  0           ['unet_up1_conv_before_concat_0_a
#                                                                  ctivation[0][0]',
#                                                                   'unet_down2_conv_1_activation[0]
#                                                                  [0]']
#
#  unet_up1_conv_after_concat_0 (  (None, 32, 32, 256)  1179648    ['unet_up1_concat[0][0]']
#  Conv2D)
#
#  unet_up1_conv_after_concat_0_b  (None, 32, 32, 256)  1024       ['unet_up1_conv_after_concat_0[0]
#  n (BatchNormalization)                                          [0]']
#
#  unet_up1_conv_after_concat_0_a  (None, 32, 32, 256)  0          ['unet_up1_conv_after_concat_0_bn
#  ctivation (ReLU)                                                [0][0]']
#
#  unet_up1_conv_after_concat_1 (  (None, 32, 32, 256)  589824     ['unet_up1_conv_after_concat_0_ac
#  Conv2D)                                                         tivation[0][0]']
#
#  unet_up1_conv_after_concat_1_b  (None, 32, 32, 256)  1024       ['unet_up1_conv_after_concat_1[0]
#  n (BatchNormalization)                                          [0]']
#
#  unet_up1_conv_after_concat_1_a  (None, 32, 32, 256)  0          ['unet_up1_conv_after_concat_1_bn
#  ctivation (ReLU)                                                [0][0]']
#
#  unet_up2_decode_unpool (UpSamp  (None, 64, 64, 256)  0          ['unet_up1_conv_after_concat_1_ac
#  ling2D)                                                         tivation[0][0]']
#
#  unet_up2_conv_before_concat_0   (None, 64, 64, 128)  294912     ['unet_up2_decode_unpool[0][0]']
#  (Conv2D)
#
#  unet_up2_conv_before_concat_0_  (None, 64, 64, 128)  512        ['unet_up2_conv_before_concat_0[0
#  bn (BatchNormalization)                                         ][0]']
#
#  unet_up2_conv_before_concat_0_  (None, 64, 64, 128)  0          ['unet_up2_conv_before_concat_0_b
#  activation (ReLU)                                               n[0][0]']
#
#  unet_up2_concat (Concatenate)  (None, 64, 64, 256)  0           ['unet_up2_conv_before_concat_0_a
#                                                                  ctivation[0][0]',
#                                                                   'unet_down1_conv_1_activation[0]
#                                                                  [0]']
#
#  unet_up2_conv_after_concat_0 (  (None, 64, 64, 128)  294912     ['unet_up2_concat[0][0]']
#  Conv2D)
#
#  unet_up2_conv_after_concat_0_b  (None, 64, 64, 128)  512        ['unet_up2_conv_after_concat_0[0]
#  n (BatchNormalization)                                          [0]']
#
#  unet_up2_conv_after_concat_0_a  (None, 64, 64, 128)  0          ['unet_up2_conv_after_concat_0_bn
#  ctivation (ReLU)                                                [0][0]']
#
#  unet_up2_conv_after_concat_1 (  (None, 64, 64, 128)  147456     ['unet_up2_conv_after_concat_0_ac
#  Conv2D)                                                         tivation[0][0]']
#
#  unet_up2_conv_after_concat_1_b  (None, 64, 64, 128)  512        ['unet_up2_conv_after_concat_1[0]
#  n (BatchNormalization)                                          [0]']
#
#  unet_up2_conv_after_concat_1_a  (None, 64, 64, 128)  0          ['unet_up2_conv_after_concat_1_bn
#  ctivation (ReLU)                                                [0][0]']
#
#  unet_up3_decode_unpool (UpSamp  (None, 128, 128, 12  0          ['unet_up2_conv_after_concat_1_ac
#  ling2D)                        8)                               tivation[0][0]']
#
#  unet_up3_conv_before_concat_0   (None, 128, 128, 64  73728      ['unet_up3_decode_unpool[0][0]']
#  (Conv2D)                       )
#
#  unet_up3_conv_before_concat_0_  (None, 128, 128, 64  256        ['unet_up3_conv_before_concat_0[0
#  bn (BatchNormalization)        )                                ][0]']
#
#  unet_up3_conv_before_concat_0_  (None, 128, 128, 64  0          ['unet_up3_conv_before_concat_0_b
#  activation (ReLU)              )                                n[0][0]']
#
#  unet_up3_concat (Concatenate)  (None, 128, 128, 12  0           ['unet_up3_conv_before_concat_0_a
#                                 8)                               ctivation[0][0]',
#                                                                   'unet_down0_1_activation[0][0]']
#
#  unet_up3_conv_after_concat_0 (  (None, 128, 128, 64  73728      ['unet_up3_concat[0][0]']
#  Conv2D)                        )
#
#  unet_up3_conv_after_concat_0_b  (None, 128, 128, 64  256        ['unet_up3_conv_after_concat_0[0]
#  n (BatchNormalization)         )                                [0]']
#
#  unet_up3_conv_after_concat_0_a  (None, 128, 128, 64  0          ['unet_up3_conv_after_concat_0_bn
#  ctivation (ReLU)               )                                [0][0]']
#
#  unet_up3_conv_after_concat_1 (  (None, 128, 128, 64  36864      ['unet_up3_conv_after_concat_0_ac
#  Conv2D)                        )                                tivation[0][0]']
#
#  unet_up3_conv_after_concat_1_b  (None, 128, 128, 64  256        ['unet_up3_conv_after_concat_1[0]
#  n (BatchNormalization)         )                                [0]']
#
#  unet_up3_conv_after_concat_1_a  (None, 128, 128, 64  0          ['unet_up3_conv_after_concat_1_bn
#  ctivation (ReLU)               )                                [0][0]']
#
#  unet_output (Conv2D)           (None, 128, 128, 1)  65          ['unet_up3_conv_after_concat_1_ac
#                                                                  tivation[0][0]']
#
#  unet_output_activation (Activa  (None, 128, 128, 1)  0          ['unet_output[0][0]']
#  tion)
#
# ==================================================================================================
# Total params: 34,540,225
# Trainable params: 34,526,529
# Non-trainable params: 13,696
# __________________________________________________________________________________________________

# %%
def jaccard_coef(y_true, y_pred):
    # Cast tensors to float32
    y_true_f = tf.cast(tf.keras.backend.flatten(y_true), tf.float32)
    y_pred_f = tf.cast(tf.keras.backend.flatten(y_pred), tf.float32)
    
    # Calculate the intersection
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    
    # Calculate the sum of both predictions and true values, then subtract intersection to get union
    union = tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection
    
    # Smooth term to avoid division by zero
    smooth = 1.0
    
    # Compute Jaccard index
    jaccard_index = (intersection + smooth) / (union + smooth)
    return jaccard_index

def jaccard_coef_loss(y_true, y_pred):
    return -jaccard_coef(y_true, y_pred)

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# %%
filepath = ("Models/"+model.name+"_best-model.hdf5")

# %%
checkpoint = ModelCheckpoint(filepath, monitor='val_iou_score', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor="loss", factor=0.3, patience=10, verbose=1, cooldown=10, min_lr=1e-5)
lr_shceduler = LearningRateScheduler(lambda _, lr: lr * np.exp(-0.01), verbose=1)
tensorboard = keras.callbacks.TensorBoard("logs/1_r2a", update_freq=1)

callbacks_list = [reduce_lr, lr_shceduler, tensorboard, checkpoint]

# %%
model.compile(#optimizer=keras.optimizers.SGD(lr=1e-3), 
#              optimizer = 'adam',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#              loss = 'binary_crossentropy',
              loss=jaccard_coef_loss,  
              #loss=losses.iou_seg,
#              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#              loss=tf.keras.losses.BinaryFocalCrossentropy(gamma=2.0, from_logits=True),
              metrics=['accuracy', 
                       losses.iou_seg, 
                       tf.keras.metrics.MeanIoU(num_classes=2), 
                       tf.keras.metrics.Recall(), 
                       sm.metrics.iou_score,
                       tf.keras.metrics.Precision()])

# %%
callback = [tf.keras.callbacks.LearningRateScheduler(scheduler), checkpoint]

# %%
start1 = datetime.now() 

model_history = model.fit(X_train, y_train, 
                    batch_size = 8, 
                    verbose=1, 
                    epochs=150, 
                    validation_data=(X_test, y_test),
                    #callbacks=callbacks_list,
                    callbacks=[callback],
                    shuffle=False)
#model.save(model.name+'.hdf5')
stop1 = datetime.now()
execution_time_model = stop1-start1
print(model.name+" execution time is: ", execution_time_model)
# Out:
# Epoch 1/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0145 - accuracy: 0.8425 - iou_seg: 0.9856 - mean_io_u: 0.5054 - recall: 0.5384 - iou_score: 0.0144 - precision: 0.0147
# Epoch 1: val_iou_score improved from -inf to 0.00551, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 27s 135ms/step - loss: -0.0145 - accuracy: 0.8425 - iou_seg: 0.9856 - mean_io_u: 0.5054 - recall: 0.5384 - iou_score: 0.0144 - precision: 0.0147 - val_loss: -0.0055 - val_accuracy: 0.3728 - val_iou_seg: 0.9945 - val_mean_io_u: 0.2819 - val_recall: 0.8372 - val_iou_score: 0.0055 - val_precision: 0.0057 - lr: 0.0010
# Epoch 2/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0290 - accuracy: 0.9712 - iou_seg: 0.9713 - mean_io_u: 0.5146 - recall: 0.2187 - iou_score: 0.0287 - precision: 0.0356
# Epoch 2: val_iou_score improved from 0.00551 to 0.00881, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 11s 100ms/step - loss: -0.0290 - accuracy: 0.9712 - iou_seg: 0.9713 - mean_io_u: 0.5146 - recall: 0.2187 - iou_score: 0.0287 - precision: 0.0356 - val_loss: -0.0088 - val_accuracy: 0.6821 - val_iou_seg: 0.9912 - val_mean_io_u: 0.5021 - val_recall: 0.6869 - val_iou_score: 0.0088 - val_precision: 0.0092 - lr: 0.0010
# Epoch 3/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0584 - accuracy: 0.9873 - iou_seg: 0.9422 - mean_io_u: 0.5153 - recall: 0.1954 - iou_score: 0.0578 - precision: 0.0831
# Epoch 3: val_iou_score improved from 0.00881 to 0.02954, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 11s 100ms/step - loss: -0.0584 - accuracy: 0.9873 - iou_seg: 0.9422 - mean_io_u: 0.5153 - recall: 0.1954 - iou_score: 0.0578 - precision: 0.0831 - val_loss: -0.0298 - val_accuracy: 0.9625 - val_iou_seg: 0.9705 - val_mean_io_u: 0.5301 - val_recall: 0.2510 - val_iou_score: 0.0295 - val_precision: 0.0302 - lr: 0.0010
# Epoch 4/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0657 - accuracy: 0.9908 - iou_seg: 0.9351 - mean_io_u: 0.5168 - recall: 0.1627 - iou_score: 0.0649 - precision: 0.1106
# Epoch 4: val_iou_score did not improve from 0.02954
# 114/114 [==============================] - 11s 95ms/step - loss: -0.0657 - accuracy: 0.9908 - iou_seg: 0.9351 - mean_io_u: 0.5168 - recall: 0.1627 - iou_score: 0.0649 - precision: 0.1106 - val_loss: -0.0110 - val_accuracy: 0.7437 - val_iou_seg: 0.9890 - val_mean_io_u: 0.4258 - val_recall: 0.6764 - val_iou_score: 0.0110 - val_precision: 0.0112 - lr: 0.0010
# Epoch 5/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0791 - accuracy: 0.9915 - iou_seg: 0.9217 - mean_io_u: 0.5236 - recall: 0.1822 - iou_score: 0.0783 - precision: 0.1354
# Epoch 5: val_iou_score improved from 0.02954 to 0.07059, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 11s 100ms/step - loss: -0.0791 - accuracy: 0.9915 - iou_seg: 0.9217 - mean_io_u: 0.5236 - recall: 0.1822 - iou_score: 0.0783 - precision: 0.1354 - val_loss: -0.0712 - val_accuracy: 0.9828 - val_iou_seg: 0.9294 - val_mean_io_u: 0.5462 - val_recall: 0.3224 - val_iou_score: 0.0706 - val_precision: 0.0877 - lr: 0.0010
# Epoch 6/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0869 - accuracy: 0.9919 - iou_seg: 0.9139 - mean_io_u: 0.5310 - recall: 0.1894 - iou_score: 0.0861 - precision: 0.1493
# Epoch 6: val_iou_score did not improve from 0.07059
# 114/114 [==============================] - 12s 106ms/step - loss: -0.0869 - accuracy: 0.9919 - iou_seg: 0.9139 - mean_io_u: 0.5310 - recall: 0.1894 - iou_score: 0.0861 - precision: 0.1493 - val_loss: -0.0288 - val_accuracy: 0.9253 - val_iou_seg: 0.9713 - val_mean_io_u: 0.5040 - val_recall: 0.5183 - val_iou_score: 0.0287 - val_precision: 0.0295 - lr: 0.0010
# Epoch 7/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0928 - accuracy: 0.9914 - iou_seg: 0.9080 - mean_io_u: 0.5368 - recall: 0.2132 - iou_score: 0.0920 - precision: 0.1498
# Epoch 7: val_iou_score did not improve from 0.07059
# 114/114 [==============================] - 11s 99ms/step - loss: -0.0928 - accuracy: 0.9914 - iou_seg: 0.9080 - mean_io_u: 0.5368 - recall: 0.2132 - iou_score: 0.0920 - precision: 0.1498 - val_loss: -0.0234 - val_accuracy: 0.9137 - val_iou_seg: 0.9767 - val_mean_io_u: 0.4997 - val_recall: 0.4952 - val_iou_score: 0.0233 - val_precision: 0.0245 - lr: 0.0010
# Epoch 8/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0983 - accuracy: 0.9921 - iou_seg: 0.9026 - mean_io_u: 0.5354 - recall: 0.2131 - iou_score: 0.0974 - precision: 0.1691
# Epoch 8: val_iou_score improved from 0.07059 to 0.07603, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 12s 103ms/step - loss: -0.0983 - accuracy: 0.9921 - iou_seg: 0.9026 - mean_io_u: 0.5354 - recall: 0.2131 - iou_score: 0.0974 - precision: 0.1691 - val_loss: -0.0777 - val_accuracy: 0.9949 - val_iou_seg: 0.9240 - val_mean_io_u: 0.5359 - val_recall: 0.1374 - val_iou_score: 0.0760 - val_precision: 0.2881 - lr: 0.0010
# Epoch 9/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0995 - accuracy: 0.9923 - iou_seg: 0.9013 - mean_io_u: 0.5371 - recall: 0.2152 - iou_score: 0.0987 - precision: 0.1752
# Epoch 9: val_iou_score did not improve from 0.07603
# 114/114 [==============================] - 11s 95ms/step - loss: -0.0995 - accuracy: 0.9923 - iou_seg: 0.9013 - mean_io_u: 0.5371 - recall: 0.2152 - iou_score: 0.0987 - precision: 0.1752 - val_loss: -0.0755 - val_accuracy: 0.9802 - val_iou_seg: 0.9249 - val_mean_io_u: 0.5555 - val_recall: 0.4091 - val_iou_score: 0.0751 - val_precision: 0.0914 - lr: 0.0010
# Epoch 10/150
# 114/114 [==============================] - ETA: 0s - loss: -0.0999 - accuracy: 0.9922 - iou_seg: 0.9009 - mean_io_u: 0.5371 - recall: 0.2136 - iou_score: 0.0991 - precision: 0.1707
# Epoch 10: val_iou_score improved from 0.07603 to 0.08722, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 11s 100ms/step - loss: -0.0999 - accuracy: 0.9922 - iou_seg: 0.9009 - mean_io_u: 0.5371 - recall: 0.2136 - iou_score: 0.0991 - precision: 0.1707 - val_loss: -0.0882 - val_accuracy: 0.9885 - val_iou_seg: 0.9128 - val_mean_io_u: 0.5479 - val_recall: 0.2775 - val_iou_score: 0.0872 - val_precision: 0.1235 - lr: 0.0010
# Epoch 11/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1075 - accuracy: 0.9925 - iou_seg: 0.8934 - mean_io_u: 0.5423 - recall: 0.2191 - iou_score: 0.1066 - precision: 0.1861
# Epoch 11: val_iou_score improved from 0.08722 to 0.09748, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 12s 102ms/step - loss: -0.1075 - accuracy: 0.9925 - iou_seg: 0.8934 - mean_io_u: 0.5423 - recall: 0.2191 - iou_score: 0.1066 - precision: 0.1861 - val_loss: -0.0988 - val_accuracy: 0.9940 - val_iou_seg: 0.9025 - val_mean_io_u: 0.5386 - val_recall: 0.1818 - val_iou_score: 0.0975 - val_precision: 0.2346 - lr: 9.0484e-04
# Epoch 12/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1128 - accuracy: 0.9923 - iou_seg: 0.8881 - mean_io_u: 0.5458 - recall: 0.2389 - iou_score: 0.1119 - precision: 0.1893
# Epoch 12: val_iou_score improved from 0.09748 to 0.10921, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 14s 125ms/step - loss: -0.1128 - accuracy: 0.9923 - iou_seg: 0.8881 - mean_io_u: 0.5458 - recall: 0.2389 - iou_score: 0.1119 - precision: 0.1893 - val_loss: -0.1105 - val_accuracy: 0.9936 - val_iou_seg: 0.8908 - val_mean_io_u: 0.5494 - val_recall: 0.2250 - val_iou_score: 0.1092 - val_precision: 0.2340 - lr: 8.1873e-04
# Epoch 13/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1165 - accuracy: 0.9925 - iou_seg: 0.8844 - mean_io_u: 0.5495 - recall: 0.2377 - iou_score: 0.1156 - precision: 0.1944
# Epoch 13: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 12s 105ms/step - loss: -0.1165 - accuracy: 0.9925 - iou_seg: 0.8844 - mean_io_u: 0.5495 - recall: 0.2377 - iou_score: 0.1156 - precision: 0.1944 - val_loss: -0.0474 - val_accuracy: 0.9602 - val_iou_seg: 0.9529 - val_mean_io_u: 0.5197 - val_recall: 0.4368 - val_iou_score: 0.0471 - val_precision: 0.0474 - lr: 7.4082e-04
# Epoch 14/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1232 - accuracy: 0.9926 - iou_seg: 0.8776 - mean_io_u: 0.5540 - recall: 0.2490 - iou_score: 0.1224 - precision: 0.2041
# Epoch 14: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 11s 99ms/step - loss: -0.1232 - accuracy: 0.9926 - iou_seg: 0.8776 - mean_io_u: 0.5540 - recall: 0.2490 - iou_score: 0.1224 - precision: 0.2041 - val_loss: -0.0624 - val_accuracy: 0.9953 - val_iou_seg: 0.9396 - val_mean_io_u: 0.5232 - val_recall: 0.0980 - val_iou_score: 0.0604 - val_precision: 0.3299 - lr: 6.7032e-04
# Epoch 15/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1313 - accuracy: 0.9931 - iou_seg: 0.8697 - mean_io_u: 0.5567 - recall: 0.2523 - iou_score: 0.1303 - precision: 0.2268
# Epoch 15: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 12s 101ms/step - loss: -0.1313 - accuracy: 0.9931 - iou_seg: 0.8697 - mean_io_u: 0.5567 - recall: 0.2523 - iou_score: 0.1303 - precision: 0.2268 - val_loss: -0.1087 - val_accuracy: 0.9934 - val_iou_seg: 0.8926 - val_mean_io_u: 0.5536 - val_recall: 0.2266 - val_iou_score: 0.1074 - val_precision: 0.2264 - lr: 6.0653e-04
# Epoch 16/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1399 - accuracy: 0.9935 - iou_seg: 0.8611 - mean_io_u: 0.5607 - recall: 0.2618 - iou_score: 0.1389 - precision: 0.2526
# Epoch 16: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 12s 102ms/step - loss: -0.1399 - accuracy: 0.9935 - iou_seg: 0.8611 - mean_io_u: 0.5607 - recall: 0.2618 - iou_score: 0.1389 - precision: 0.2526 - val_loss: -0.0576 - val_accuracy: 0.9955 - val_iou_seg: 0.9445 - val_mean_io_u: 0.5242 - val_recall: 0.0895 - val_iou_score: 0.0555 - val_precision: 0.3713 - lr: 5.4881e-04
# Epoch 17/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1422 - accuracy: 0.9936 - iou_seg: 0.8588 - mean_io_u: 0.5626 - recall: 0.2622 - iou_score: 0.1412 - precision: 0.2580
# Epoch 17: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 13s 118ms/step - loss: -0.1422 - accuracy: 0.9936 - iou_seg: 0.8588 - mean_io_u: 0.5626 - recall: 0.2622 - iou_score: 0.1412 - precision: 0.2580 - val_loss: -0.0654 - val_accuracy: 0.9811 - val_iou_seg: 0.9353 - val_mean_io_u: 0.5337 - val_recall: 0.2831 - val_iou_score: 0.0647 - val_precision: 0.0709 - lr: 4.9659e-04
# Epoch 18/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1454 - accuracy: 0.9937 - iou_seg: 0.8556 - mean_io_u: 0.5620 - recall: 0.2627 - iou_score: 0.1444 - precision: 0.2676
# Epoch 18: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 14s 127ms/step - loss: -0.1454 - accuracy: 0.9937 - iou_seg: 0.8556 - mean_io_u: 0.5620 - recall: 0.2627 - iou_score: 0.1444 - precision: 0.2676 - val_loss: -0.1058 - val_accuracy: 0.9937 - val_iou_seg: 0.8957 - val_mean_io_u: 0.5499 - val_recall: 0.2118 - val_iou_score: 0.1043 - val_precision: 0.2345 - lr: 4.4933e-04
# Epoch 19/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1520 - accuracy: 0.9940 - iou_seg: 0.8490 - mean_io_u: 0.5662 - recall: 0.2729 - iou_score: 0.1510 - precision: 0.2861
# Epoch 19: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 14s 121ms/step - loss: -0.1520 - accuracy: 0.9940 - iou_seg: 0.8490 - mean_io_u: 0.5662 - recall: 0.2729 - iou_score: 0.1510 - precision: 0.2861 - val_loss: -0.0890 - val_accuracy: 0.9943 - val_iou_seg: 0.9125 - val_mean_io_u: 0.5411 - val_recall: 0.1596 - val_iou_score: 0.0875 - val_precision: 0.2407 - lr: 4.0657e-04
# Epoch 20/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1555 - accuracy: 0.9941 - iou_seg: 0.8456 - mean_io_u: 0.5670 - recall: 0.2721 - iou_score: 0.1544 - precision: 0.2995
# Epoch 20: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 13s 115ms/step - loss: -0.1555 - accuracy: 0.9941 - iou_seg: 0.8456 - mean_io_u: 0.5670 - recall: 0.2721 - iou_score: 0.1544 - precision: 0.2995 - val_loss: -0.0774 - val_accuracy: 0.9952 - val_iou_seg: 0.9244 - val_mean_io_u: 0.5362 - val_recall: 0.1285 - val_iou_score: 0.0756 - val_precision: 0.3362 - lr: 3.6788e-04
# Epoch 21/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1640 - accuracy: 0.9943 - iou_seg: 0.8371 - mean_io_u: 0.5725 - recall: 0.2845 - iou_score: 0.1629 - precision: 0.3169
# Epoch 21: val_iou_score did not improve from 0.10921
# 114/114 [==============================] - 12s 106ms/step - loss: -0.1640 - accuracy: 0.9943 - iou_seg: 0.8371 - mean_io_u: 0.5725 - recall: 0.2845 - iou_score: 0.1629 - precision: 0.3169 - val_loss: -0.0714 - val_accuracy: 0.9954 - val_iou_seg: 0.9305 - val_mean_io_u: 0.5314 - val_recall: 0.1150 - val_iou_score: 0.0695 - val_precision: 0.3606 - lr: 3.3287e-04
# Epoch 22/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1649 - accuracy: 0.9944 - iou_seg: 0.8362 - mean_io_u: 0.5738 - recall: 0.2819 - iou_score: 0.1638 - precision: 0.3251
# Epoch 22: val_iou_score improved from 0.10921 to 0.10979, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 13s 115ms/step - loss: -0.1649 - accuracy: 0.9944 - iou_seg: 0.8362 - mean_io_u: 0.5738 - recall: 0.2819 - iou_score: 0.1638 - precision: 0.3251 - val_loss: -0.1111 - val_accuracy: 0.9937 - val_iou_seg: 0.8902 - val_mean_io_u: 0.5546 - val_recall: 0.2188 - val_iou_score: 0.1098 - val_precision: 0.2358 - lr: 3.0119e-04
# Epoch 23/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1688 - accuracy: 0.9944 - iou_seg: 0.8323 - mean_io_u: 0.5738 - recall: 0.2834 - iou_score: 0.1677 - precision: 0.3258
# Epoch 23: val_iou_score did not improve from 0.10979
# 114/114 [==============================] - 13s 110ms/step - loss: -0.1688 - accuracy: 0.9944 - iou_seg: 0.8323 - mean_io_u: 0.5738 - recall: 0.2834 - iou_score: 0.1677 - precision: 0.3258 - val_loss: -0.0867 - val_accuracy: 0.9948 - val_iou_seg: 0.9151 - val_mean_io_u: 0.5424 - val_recall: 0.1464 - val_iou_score: 0.0849 - val_precision: 0.2894 - lr: 2.7253e-04
# Epoch 24/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1756 - accuracy: 0.9947 - iou_seg: 0.8255 - mean_io_u: 0.5770 - recall: 0.2871 - iou_score: 0.1745 - precision: 0.3557
# Epoch 24: val_iou_score improved from 0.10979 to 0.11044, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 12s 106ms/step - loss: -0.1756 - accuracy: 0.9947 - iou_seg: 0.8255 - mean_io_u: 0.5770 - recall: 0.2871 - iou_score: 0.1745 - precision: 0.3557 - val_loss: -0.1119 - val_accuracy: 0.9945 - val_iou_seg: 0.8896 - val_mean_io_u: 0.5565 - val_recall: 0.2003 - val_iou_score: 0.1104 - val_precision: 0.2863 - lr: 2.4660e-04
# Epoch 25/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1769 - accuracy: 0.9946 - iou_seg: 0.8243 - mean_io_u: 0.5795 - recall: 0.2981 - iou_score: 0.1757 - precision: 0.3489
# Epoch 25: val_iou_score did not improve from 0.11044
# 114/114 [==============================] - 13s 115ms/step - loss: -0.1769 - accuracy: 0.9946 - iou_seg: 0.8243 - mean_io_u: 0.5795 - recall: 0.2981 - iou_score: 0.1757 - precision: 0.3489 - val_loss: -0.1084 - val_accuracy: 0.9949 - val_iou_seg: 0.8933 - val_mean_io_u: 0.5536 - val_recall: 0.1867 - val_iou_score: 0.1067 - val_precision: 0.3248 - lr: 2.2313e-04
# Epoch 26/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1802 - accuracy: 0.9947 - iou_seg: 0.8209 - mean_io_u: 0.5811 - recall: 0.2993 - iou_score: 0.1791 - precision: 0.3591
# Epoch 26: val_iou_score did not improve from 0.11044
# 114/114 [==============================] - 16s 144ms/step - loss: -0.1802 - accuracy: 0.9947 - iou_seg: 0.8209 - mean_io_u: 0.5811 - recall: 0.2993 - iou_score: 0.1791 - precision: 0.3591 - val_loss: -0.1093 - val_accuracy: 0.9949 - val_iou_seg: 0.8923 - val_mean_io_u: 0.5562 - val_recall: 0.1955 - val_iou_score: 0.1077 - val_precision: 0.3300 - lr: 2.0190e-04
# Epoch 27/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1826 - accuracy: 0.9948 - iou_seg: 0.8186 - mean_io_u: 0.5817 - recall: 0.2970 - iou_score: 0.1814 - precision: 0.3746
# Epoch 27: val_iou_score did not improve from 0.11044
# 114/114 [==============================] - 17s 151ms/step - loss: -0.1826 - accuracy: 0.9948 - iou_seg: 0.8186 - mean_io_u: 0.5817 - recall: 0.2970 - iou_score: 0.1814 - precision: 0.3746 - val_loss: -0.1049 - val_accuracy: 0.9925 - val_iou_seg: 0.8963 - val_mean_io_u: 0.5592 - val_recall: 0.2370 - val_iou_score: 0.1037 - val_precision: 0.1932 - lr: 1.8268e-04
# Epoch 28/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1893 - accuracy: 0.9949 - iou_seg: 0.8119 - mean_io_u: 0.5845 - recall: 0.3046 - iou_score: 0.1881 - precision: 0.3818
# Epoch 28: val_iou_score improved from 0.11044 to 0.11167, saving model to Models\unet_model_best-model.hdf5
# 114/114 [==============================] - 15s 133ms/step - loss: -0.1893 - accuracy: 0.9949 - iou_seg: 0.8119 - mean_io_u: 0.5845 - recall: 0.3046 - iou_score: 0.1881 - precision: 0.3818 - val_loss: -0.1131 - val_accuracy: 0.9942 - val_iou_seg: 0.8883 - val_mean_io_u: 0.5595 - val_recall: 0.2146 - val_iou_score: 0.1117 - val_precision: 0.2711 - lr: 1.6530e-04
# Epoch 29/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1935 - accuracy: 0.9951 - iou_seg: 0.8077 - mean_io_u: 0.5866 - recall: 0.3086 - iou_score: 0.1923 - precision: 0.4038
# Epoch 29: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 14s 122ms/step - loss: -0.1935 - accuracy: 0.9951 - iou_seg: 0.8077 - mean_io_u: 0.5866 - recall: 0.3086 - iou_score: 0.1923 - precision: 0.4038 - val_loss: -0.1081 - val_accuracy: 0.9939 - val_iou_seg: 0.8933 - val_mean_io_u: 0.5597 - val_recall: 0.2128 - val_iou_score: 0.1067 - val_precision: 0.2454 - lr: 1.4957e-04
# Epoch 30/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1967 - accuracy: 0.9951 - iou_seg: 0.8046 - mean_io_u: 0.5872 - recall: 0.3093 - iou_score: 0.1954 - precision: 0.4071
# Epoch 30: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 14s 122ms/step - loss: -0.1967 - accuracy: 0.9951 - iou_seg: 0.8046 - mean_io_u: 0.5872 - recall: 0.3093 - iou_score: 0.1954 - precision: 0.4071 - val_loss: -0.1094 - val_accuracy: 0.9937 - val_iou_seg: 0.8920 - val_mean_io_u: 0.5605 - val_recall: 0.2182 - val_iou_score: 0.1080 - val_precision: 0.2377 - lr: 1.3534e-04
# Epoch 31/150
# 114/114 [==============================] - ETA: 0s - loss: -0.1990 - accuracy: 0.9951 - iou_seg: 0.8023 - mean_io_u: 0.5877 - recall: 0.3136 - iou_score: 0.1977 - precision: 0.4126
# Epoch 31: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 13s 110ms/step - loss: -0.1990 - accuracy: 0.9951 - iou_seg: 0.8023 - mean_io_u: 0.5877 - recall: 0.3136 - iou_score: 0.1977 - precision: 0.4126 - val_loss: -0.1121 - val_accuracy: 0.9935 - val_iou_seg: 0.8892 - val_mean_io_u: 0.5629 - val_recall: 0.2352 - val_iou_score: 0.1108 - val_precision: 0.2347 - lr: 1.2246e-04
# Epoch 32/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2033 - accuracy: 0.9952 - iou_seg: 0.7979 - mean_io_u: 0.5882 - recall: 0.3146 - iou_score: 0.2021 - precision: 0.4272
# Epoch 32: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 108ms/step - loss: -0.2033 - accuracy: 0.9952 - iou_seg: 0.7979 - mean_io_u: 0.5882 - recall: 0.3146 - iou_score: 0.2021 - precision: 0.4272 - val_loss: -0.1101 - val_accuracy: 0.9942 - val_iou_seg: 0.8912 - val_mean_io_u: 0.5617 - val_recall: 0.2124 - val_iou_score: 0.1088 - val_precision: 0.2702 - lr: 1.1080e-04
# Epoch 33/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2044 - accuracy: 0.9952 - iou_seg: 0.7968 - mean_io_u: 0.5896 - recall: 0.3203 - iou_score: 0.2032 - precision: 0.4202
# Epoch 33: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 108ms/step - loss: -0.2044 - accuracy: 0.9952 - iou_seg: 0.7968 - mean_io_u: 0.5896 - recall: 0.3203 - iou_score: 0.2032 - precision: 0.4202 - val_loss: -0.1098 - val_accuracy: 0.9936 - val_iou_seg: 0.8915 - val_mean_io_u: 0.5638 - val_recall: 0.2281 - val_iou_score: 0.1085 - val_precision: 0.2393 - lr: 1.0026e-04
# Epoch 34/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2091 - accuracy: 0.9953 - iou_seg: 0.7922 - mean_io_u: 0.5917 - recall: 0.3238 - iou_score: 0.2078 - precision: 0.4357
# Epoch 34: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 108ms/step - loss: -0.2091 - accuracy: 0.9953 - iou_seg: 0.7922 - mean_io_u: 0.5917 - recall: 0.3238 - iou_score: 0.2078 - precision: 0.4357 - val_loss: -0.1075 - val_accuracy: 0.9949 - val_iou_seg: 0.8941 - val_mean_io_u: 0.5592 - val_recall: 0.1914 - val_iou_score: 0.1059 - val_precision: 0.3293 - lr: 9.0718e-05
# Epoch 35/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2110 - accuracy: 0.9953 - iou_seg: 0.7903 - mean_io_u: 0.5930 - recall: 0.3269 - iou_score: 0.2097 - precision: 0.4374
# Epoch 35: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 108ms/step - loss: -0.2110 - accuracy: 0.9953 - iou_seg: 0.7903 - mean_io_u: 0.5930 - recall: 0.3269 - iou_score: 0.2097 - precision: 0.4374 - val_loss: -0.1111 - val_accuracy: 0.9949 - val_iou_seg: 0.8905 - val_mean_io_u: 0.5579 - val_recall: 0.1951 - val_iou_score: 0.1095 - val_precision: 0.3363 - lr: 8.2085e-05
# Epoch 36/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2144 - accuracy: 0.9954 - iou_seg: 0.7869 - mean_io_u: 0.5933 - recall: 0.3271 - iou_score: 0.2131 - precision: 0.4480
# Epoch 36: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 107ms/step - loss: -0.2144 - accuracy: 0.9954 - iou_seg: 0.7869 - mean_io_u: 0.5933 - recall: 0.3271 - iou_score: 0.2131 - precision: 0.4480 - val_loss: -0.1130 - val_accuracy: 0.9941 - val_iou_seg: 0.8883 - val_mean_io_u: 0.5633 - val_recall: 0.2205 - val_iou_score: 0.1117 - val_precision: 0.2697 - lr: 7.4273e-05
# Epoch 37/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2143 - accuracy: 0.9954 - iou_seg: 0.7869 - mean_io_u: 0.5932 - recall: 0.3289 - iou_score: 0.2131 - precision: 0.4494
# Epoch 37: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 108ms/step - loss: -0.2143 - accuracy: 0.9954 - iou_seg: 0.7869 - mean_io_u: 0.5932 - recall: 0.3289 - iou_score: 0.2131 - precision: 0.4494 - val_loss: -0.1092 - val_accuracy: 0.9950 - val_iou_seg: 0.8924 - val_mean_io_u: 0.5572 - val_recall: 0.1904 - val_iou_score: 0.1076 - val_precision: 0.3505 - lr: 6.7205e-05
# Epoch 38/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2163 - accuracy: 0.9954 - iou_seg: 0.7850 - mean_io_u: 0.5937 - recall: 0.3296 - iou_score: 0.2150 - precision: 0.4536
# Epoch 38: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 108ms/step - loss: -0.2163 - accuracy: 0.9954 - iou_seg: 0.7850 - mean_io_u: 0.5937 - recall: 0.3296 - iou_score: 0.2150 - precision: 0.4536 - val_loss: -0.1126 - val_accuracy: 0.9948 - val_iou_seg: 0.8889 - val_mean_io_u: 0.5595 - val_recall: 0.2029 - val_iou_score: 0.1111 - val_precision: 0.3182 - lr: 6.0810e-05
# Epoch 39/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2197 - accuracy: 0.9955 - iou_seg: 0.7816 - mean_io_u: 0.5956 - recall: 0.3314 - iou_score: 0.2184 - precision: 0.4621
# Epoch 39: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 107ms/step - loss: -0.2197 - accuracy: 0.9955 - iou_seg: 0.7816 - mean_io_u: 0.5956 - recall: 0.3314 - iou_score: 0.2184 - precision: 0.4621 - val_loss: -0.1107 - val_accuracy: 0.9950 - val_iou_seg: 0.8908 - val_mean_io_u: 0.5579 - val_recall: 0.1919 - val_iou_score: 0.1092 - val_precision: 0.3438 - lr: 5.5023e-05
# Epoch 40/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2210 - accuracy: 0.9955 - iou_seg: 0.7803 - mean_io_u: 0.5951 - recall: 0.3331 - iou_score: 0.2197 - precision: 0.4637
# Epoch 40: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 108ms/step - loss: -0.2210 - accuracy: 0.9955 - iou_seg: 0.7803 - mean_io_u: 0.5951 - recall: 0.3331 - iou_score: 0.2197 - precision: 0.4637 - val_loss: -0.1109 - val_accuracy: 0.9949 - val_iou_seg: 0.8906 - val_mean_io_u: 0.5581 - val_recall: 0.1952 - val_iou_score: 0.1094 - val_precision: 0.3365 - lr: 4.9787e-05
# Epoch 41/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2223 - accuracy: 0.9955 - iou_seg: 0.7791 - mean_io_u: 0.5951 - recall: 0.3334 - iou_score: 0.2209 - precision: 0.4718
# Epoch 41: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 107ms/step - loss: -0.2223 - accuracy: 0.9955 - iou_seg: 0.7791 - mean_io_u: 0.5951 - recall: 0.3334 - iou_score: 0.2209 - precision: 0.4718 - val_loss: -0.1085 - val_accuracy: 0.9951 - val_iou_seg: 0.8931 - val_mean_io_u: 0.5567 - val_recall: 0.1855 - val_iou_score: 0.1069 - val_precision: 0.3565 - lr: 4.5049e-05
# Epoch 42/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2243 - accuracy: 0.9955 - iou_seg: 0.7770 - mean_io_u: 0.5966 - recall: 0.3366 - iou_score: 0.2230 - precision: 0.4709
# Epoch 42: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 107ms/step - loss: -0.2243 - accuracy: 0.9955 - iou_seg: 0.7770 - mean_io_u: 0.5966 - recall: 0.3366 - iou_score: 0.2230 - precision: 0.4709 - val_loss: -0.1085 - val_accuracy: 0.9951 - val_iou_seg: 0.8931 - val_mean_io_u: 0.5554 - val_recall: 0.1845 - val_iou_score: 0.1069 - val_precision: 0.3601 - lr: 4.0762e-05
# Epoch 43/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2260 - accuracy: 0.9956 - iou_seg: 0.7753 - mean_io_u: 0.5967 - recall: 0.3354 - iou_score: 0.2247 - precision: 0.4821
# Epoch 43: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 13s 115ms/step - loss: -0.2260 - accuracy: 0.9956 - iou_seg: 0.7753 - mean_io_u: 0.5967 - recall: 0.3354 - iou_score: 0.2247 - precision: 0.4821 - val_loss: -0.1030 - val_accuracy: 0.9953 - val_iou_seg: 0.8987 - val_mean_io_u: 0.5531 - val_recall: 0.1725 - val_iou_score: 0.1013 - val_precision: 0.3800 - lr: 3.6883e-05
# Epoch 44/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2277 - accuracy: 0.9956 - iou_seg: 0.7736 - mean_io_u: 0.5979 - recall: 0.3380 - iou_score: 0.2264 - precision: 0.4844
# Epoch 44: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 101ms/step - loss: -0.2277 - accuracy: 0.9956 - iou_seg: 0.7736 - mean_io_u: 0.5979 - recall: 0.3380 - iou_score: 0.2264 - precision: 0.4844 - val_loss: -0.1073 - val_accuracy: 0.9951 - val_iou_seg: 0.8943 - val_mean_io_u: 0.5558 - val_recall: 0.1841 - val_iou_score: 0.1057 - val_precision: 0.3627 - lr: 3.3373e-05
# Epoch 45/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2298 - accuracy: 0.9957 - iou_seg: 0.7715 - mean_io_u: 0.5980 - recall: 0.3390 - iou_score: 0.2285 - precision: 0.4911
# Epoch 45: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2298 - accuracy: 0.9957 - iou_seg: 0.7715 - mean_io_u: 0.5980 - recall: 0.3390 - iou_score: 0.2285 - precision: 0.4911 - val_loss: -0.1055 - val_accuracy: 0.9952 - val_iou_seg: 0.8962 - val_mean_io_u: 0.5548 - val_recall: 0.1788 - val_iou_score: 0.1038 - val_precision: 0.3718 - lr: 3.0197e-05
# Epoch 46/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2310 - accuracy: 0.9957 - iou_seg: 0.7703 - mean_io_u: 0.5986 - recall: 0.3397 - iou_score: 0.2297 - precision: 0.4952
# Epoch 46: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2310 - accuracy: 0.9957 - iou_seg: 0.7703 - mean_io_u: 0.5986 - recall: 0.3397 - iou_score: 0.2297 - precision: 0.4952 - val_loss: -0.1030 - val_accuracy: 0.9953 - val_iou_seg: 0.8989 - val_mean_io_u: 0.5534 - val_recall: 0.1727 - val_iou_score: 0.1011 - val_precision: 0.3849 - lr: 2.7324e-05
# Epoch 47/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2324 - accuracy: 0.9957 - iou_seg: 0.7690 - mean_io_u: 0.5989 - recall: 0.3409 - iou_score: 0.2310 - precision: 0.4995
# Epoch 47: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2324 - accuracy: 0.9957 - iou_seg: 0.7690 - mean_io_u: 0.5989 - recall: 0.3409 - iou_score: 0.2310 - precision: 0.4995 - val_loss: -0.1040 - val_accuracy: 0.9952 - val_iou_seg: 0.8977 - val_mean_io_u: 0.5540 - val_recall: 0.1749 - val_iou_score: 0.1023 - val_precision: 0.3758 - lr: 2.4723e-05
# Epoch 48/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2336 - accuracy: 0.9957 - iou_seg: 0.7678 - mean_io_u: 0.5993 - recall: 0.3418 - iou_score: 0.2322 - precision: 0.5031
# Epoch 48: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2336 - accuracy: 0.9957 - iou_seg: 0.7678 - mean_io_u: 0.5993 - recall: 0.3418 - iou_score: 0.2322 - precision: 0.5031 - val_loss: -0.1049 - val_accuracy: 0.9952 - val_iou_seg: 0.8969 - val_mean_io_u: 0.5542 - val_recall: 0.1767 - val_iou_score: 0.1031 - val_precision: 0.3696 - lr: 2.2371e-05
# Epoch 49/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2342 - accuracy: 0.9957 - iou_seg: 0.7671 - mean_io_u: 0.5993 - recall: 0.3427 - iou_score: 0.2329 - precision: 0.5031
# Epoch 49: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2342 - accuracy: 0.9957 - iou_seg: 0.7671 - mean_io_u: 0.5993 - recall: 0.3427 - iou_score: 0.2329 - precision: 0.5031 - val_loss: -0.1056 - val_accuracy: 0.9951 - val_iou_seg: 0.8961 - val_mean_io_u: 0.5554 - val_recall: 0.1808 - val_iou_score: 0.1039 - val_precision: 0.3588 - lr: 2.0242e-05
# Epoch 50/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2355 - accuracy: 0.9957 - iou_seg: 0.7659 - mean_io_u: 0.5997 - recall: 0.3446 - iou_score: 0.2341 - precision: 0.5065
# Epoch 50: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2355 - accuracy: 0.9957 - iou_seg: 0.7659 - mean_io_u: 0.5997 - recall: 0.3446 - iou_score: 0.2341 - precision: 0.5065 - val_loss: -0.1056 - val_accuracy: 0.9952 - val_iou_seg: 0.8961 - val_mean_io_u: 0.5544 - val_recall: 0.1774 - val_iou_score: 0.1039 - val_precision: 0.3681 - lr: 1.8316e-05
# Epoch 51/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2360 - accuracy: 0.9957 - iou_seg: 0.7653 - mean_io_u: 0.6001 - recall: 0.3452 - iou_score: 0.2347 - precision: 0.5064
# Epoch 51: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2360 - accuracy: 0.9957 - iou_seg: 0.7653 - mean_io_u: 0.6001 - recall: 0.3452 - iou_score: 0.2347 - precision: 0.5064 - val_loss: -0.1047 - val_accuracy: 0.9952 - val_iou_seg: 0.8971 - val_mean_io_u: 0.5543 - val_recall: 0.1768 - val_iou_score: 0.1029 - val_precision: 0.3647 - lr: 1.6573e-05
# Epoch 52/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2369 - accuracy: 0.9958 - iou_seg: 0.7645 - mean_io_u: 0.6000 - recall: 0.3454 - iou_score: 0.2355 - precision: 0.5100
# Epoch 52: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2369 - accuracy: 0.9958 - iou_seg: 0.7645 - mean_io_u: 0.6000 - recall: 0.3454 - iou_score: 0.2355 - precision: 0.5100 - val_loss: -0.1049 - val_accuracy: 0.9952 - val_iou_seg: 0.8969 - val_mean_io_u: 0.5545 - val_recall: 0.1771 - val_iou_score: 0.1031 - val_precision: 0.3669 - lr: 1.4996e-05
# Epoch 53/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2373 - accuracy: 0.9958 - iou_seg: 0.7641 - mean_io_u: 0.6002 - recall: 0.3459 - iou_score: 0.2359 - precision: 0.5103
# Epoch 53: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2373 - accuracy: 0.9958 - iou_seg: 0.7641 - mean_io_u: 0.6002 - recall: 0.3459 - iou_score: 0.2359 - precision: 0.5103 - val_loss: -0.1046 - val_accuracy: 0.9952 - val_iou_seg: 0.8972 - val_mean_io_u: 0.5551 - val_recall: 0.1782 - val_iou_score: 0.1028 - val_precision: 0.3621 - lr: 1.3569e-05
# Epoch 54/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2376 - accuracy: 0.9958 - iou_seg: 0.7637 - mean_io_u: 0.6005 - recall: 0.3458 - iou_score: 0.2363 - precision: 0.5116
# Epoch 54: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2376 - accuracy: 0.9958 - iou_seg: 0.7637 - mean_io_u: 0.6005 - recall: 0.3458 - iou_score: 0.2363 - precision: 0.5116 - val_loss: -0.1040 - val_accuracy: 0.9952 - val_iou_seg: 0.8978 - val_mean_io_u: 0.5547 - val_recall: 0.1763 - val_iou_score: 0.1022 - val_precision: 0.3668 - lr: 1.2277e-05
# Epoch 55/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2385 - accuracy: 0.9958 - iou_seg: 0.7629 - mean_io_u: 0.6005 - recall: 0.3466 - iou_score: 0.2371 - precision: 0.5146
# Epoch 55: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2385 - accuracy: 0.9958 - iou_seg: 0.7629 - mean_io_u: 0.6005 - recall: 0.3466 - iou_score: 0.2371 - precision: 0.5146 - val_loss: -0.1035 - val_accuracy: 0.9952 - val_iou_seg: 0.8983 - val_mean_io_u: 0.5543 - val_recall: 0.1758 - val_iou_score: 0.1017 - val_precision: 0.3665 - lr: 1.1109e-05
# Epoch 56/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2391 - accuracy: 0.9958 - iou_seg: 0.7623 - mean_io_u: 0.6005 - recall: 0.3466 - iou_score: 0.2377 - precision: 0.5177
# Epoch 56: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2391 - accuracy: 0.9958 - iou_seg: 0.7623 - mean_io_u: 0.6005 - recall: 0.3466 - iou_score: 0.2377 - precision: 0.5177 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5544 - val_recall: 0.1753 - val_iou_score: 0.1014 - val_precision: 0.3658 - lr: 1.0052e-05
# Epoch 57/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2395 - accuracy: 0.9958 - iou_seg: 0.7618 - mean_io_u: 0.6006 - recall: 0.3469 - iou_score: 0.2382 - precision: 0.5179
# Epoch 57: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 94ms/step - loss: -0.2395 - accuracy: 0.9958 - iou_seg: 0.7618 - mean_io_u: 0.6006 - recall: 0.3469 - iou_score: 0.2382 - precision: 0.5179 - val_loss: -0.1031 - val_accuracy: 0.9952 - val_iou_seg: 0.8987 - val_mean_io_u: 0.5546 - val_recall: 0.1756 - val_iou_score: 0.1013 - val_precision: 0.3664 - lr: 9.0953e-06
# Epoch 58/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2400 - accuracy: 0.9958 - iou_seg: 0.7614 - mean_io_u: 0.6008 - recall: 0.3472 - iou_score: 0.2386 - precision: 0.5203
# Epoch 58: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 95ms/step - loss: -0.2400 - accuracy: 0.9958 - iou_seg: 0.7614 - mean_io_u: 0.6008 - recall: 0.3472 - iou_score: 0.2386 - precision: 0.5203 - val_loss: -0.1036 - val_accuracy: 0.9952 - val_iou_seg: 0.8982 - val_mean_io_u: 0.5548 - val_recall: 0.1762 - val_iou_score: 0.1018 - val_precision: 0.3648 - lr: 8.2297e-06
# Epoch 59/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2402 - accuracy: 0.9958 - iou_seg: 0.7611 - mean_io_u: 0.6008 - recall: 0.3475 - iou_score: 0.2389 - precision: 0.5204
# Epoch 59: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 101ms/step - loss: -0.2402 - accuracy: 0.9958 - iou_seg: 0.7611 - mean_io_u: 0.6008 - recall: 0.3475 - iou_score: 0.2389 - precision: 0.5204 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5549 - val_recall: 0.1759 - val_iou_score: 0.1014 - val_precision: 0.3657 - lr: 7.4466e-06
# Epoch 60/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2405 - accuracy: 0.9958 - iou_seg: 0.7609 - mean_io_u: 0.6009 - recall: 0.3478 - iou_score: 0.2391 - precision: 0.5210
# Epoch 60: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 109ms/step - loss: -0.2405 - accuracy: 0.9958 - iou_seg: 0.7609 - mean_io_u: 0.6009 - recall: 0.3478 - iou_score: 0.2391 - precision: 0.5210 - val_loss: -0.1040 - val_accuracy: 0.9952 - val_iou_seg: 0.8978 - val_mean_io_u: 0.5551 - val_recall: 0.1768 - val_iou_score: 0.1022 - val_precision: 0.3637 - lr: 6.7379e-06
# Epoch 61/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2408 - accuracy: 0.9958 - iou_seg: 0.7606 - mean_io_u: 0.6009 - recall: 0.3480 - iou_score: 0.2394 - precision: 0.5219
# Epoch 61: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 106ms/step - loss: -0.2408 - accuracy: 0.9958 - iou_seg: 0.7606 - mean_io_u: 0.6009 - recall: 0.3480 - iou_score: 0.2394 - precision: 0.5219 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5549 - val_recall: 0.1756 - val_iou_score: 0.1014 - val_precision: 0.3659 - lr: 6.0967e-06
# Epoch 62/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2411 - accuracy: 0.9958 - iou_seg: 0.7603 - mean_io_u: 0.6012 - recall: 0.3482 - iou_score: 0.2397 - precision: 0.5228
# Epoch 62: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 13s 113ms/step - loss: -0.2411 - accuracy: 0.9958 - iou_seg: 0.7603 - mean_io_u: 0.6012 - recall: 0.3482 - iou_score: 0.2397 - precision: 0.5228 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5550 - val_recall: 0.1757 - val_iou_score: 0.1014 - val_precision: 0.3661 - lr: 5.5165e-06
# Epoch 63/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2413 - accuracy: 0.9958 - iou_seg: 0.7601 - mean_io_u: 0.6014 - recall: 0.3482 - iou_score: 0.2399 - precision: 0.5236
# Epoch 63: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 108ms/step - loss: -0.2413 - accuracy: 0.9958 - iou_seg: 0.7601 - mean_io_u: 0.6014 - recall: 0.3482 - iou_score: 0.2399 - precision: 0.5236 - val_loss: -0.1030 - val_accuracy: 0.9952 - val_iou_seg: 0.8987 - val_mean_io_u: 0.5552 - val_recall: 0.1759 - val_iou_score: 0.1013 - val_precision: 0.3647 - lr: 4.9916e-06
# Epoch 64/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2415 - accuracy: 0.9958 - iou_seg: 0.7599 - mean_io_u: 0.6014 - recall: 0.3484 - iou_score: 0.2401 - precision: 0.5243
# Epoch 64: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 13s 112ms/step - loss: -0.2415 - accuracy: 0.9958 - iou_seg: 0.7599 - mean_io_u: 0.6014 - recall: 0.3484 - iou_score: 0.2401 - precision: 0.5243 - val_loss: -0.1031 - val_accuracy: 0.9952 - val_iou_seg: 0.8987 - val_mean_io_u: 0.5552 - val_recall: 0.1759 - val_iou_score: 0.1013 - val_precision: 0.3641 - lr: 4.5166e-06
# Epoch 65/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2417 - accuracy: 0.9958 - iou_seg: 0.7597 - mean_io_u: 0.6014 - recall: 0.3484 - iou_score: 0.2403 - precision: 0.5247
# Epoch 65: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 104ms/step - loss: -0.2417 - accuracy: 0.9958 - iou_seg: 0.7597 - mean_io_u: 0.6014 - recall: 0.3484 - iou_score: 0.2403 - precision: 0.5247 - val_loss: -0.1030 - val_accuracy: 0.9952 - val_iou_seg: 0.8988 - val_mean_io_u: 0.5551 - val_recall: 0.1757 - val_iou_score: 0.1012 - val_precision: 0.3652 - lr: 4.0868e-06
# Epoch 66/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2418 - accuracy: 0.9958 - iou_seg: 0.7596 - mean_io_u: 0.6016 - recall: 0.3487 - iou_score: 0.2404 - precision: 0.5250
# Epoch 66: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 100ms/step - loss: -0.2418 - accuracy: 0.9958 - iou_seg: 0.7596 - mean_io_u: 0.6016 - recall: 0.3487 - iou_score: 0.2404 - precision: 0.5250 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8985 - val_mean_io_u: 0.5552 - val_recall: 0.1758 - val_iou_score: 0.1015 - val_precision: 0.3640 - lr: 3.6979e-06
# Epoch 67/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2419 - accuracy: 0.9958 - iou_seg: 0.7594 - mean_io_u: 0.6016 - recall: 0.3487 - iou_score: 0.2406 - precision: 0.5253
# Epoch 67: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 102ms/step - loss: -0.2419 - accuracy: 0.9958 - iou_seg: 0.7594 - mean_io_u: 0.6016 - recall: 0.3487 - iou_score: 0.2406 - precision: 0.5253 - val_loss: -0.1030 - val_accuracy: 0.9952 - val_iou_seg: 0.8988 - val_mean_io_u: 0.5552 - val_recall: 0.1758 - val_iou_score: 0.1012 - val_precision: 0.3645 - lr: 3.3460e-06
# Epoch 68/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2421 - accuracy: 0.9959 - iou_seg: 0.7593 - mean_io_u: 0.6017 - recall: 0.3488 - iou_score: 0.2407 - precision: 0.5260
# Epoch 68: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 106ms/step - loss: -0.2421 - accuracy: 0.9959 - iou_seg: 0.7593 - mean_io_u: 0.6017 - recall: 0.3488 - iou_score: 0.2407 - precision: 0.5260 - val_loss: -0.1031 - val_accuracy: 0.9952 - val_iou_seg: 0.8987 - val_mean_io_u: 0.5552 - val_recall: 0.1757 - val_iou_score: 0.1013 - val_precision: 0.3648 - lr: 3.0275e-06
# Epoch 69/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2422 - accuracy: 0.9959 - iou_seg: 0.7592 - mean_io_u: 0.6018 - recall: 0.3490 - iou_score: 0.2408 - precision: 0.5262
# Epoch 69: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 13s 115ms/step - loss: -0.2422 - accuracy: 0.9959 - iou_seg: 0.7592 - mean_io_u: 0.6018 - recall: 0.3490 - iou_score: 0.2408 - precision: 0.5262 - val_loss: -0.1031 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5553 - val_recall: 0.1758 - val_iou_score: 0.1014 - val_precision: 0.3644 - lr: 2.7394e-06
# Epoch 70/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2423 - accuracy: 0.9959 - iou_seg: 0.7591 - mean_io_u: 0.6018 - recall: 0.3490 - iou_score: 0.2409 - precision: 0.5266
# Epoch 70: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 13s 112ms/step - loss: -0.2423 - accuracy: 0.9959 - iou_seg: 0.7591 - mean_io_u: 0.6018 - recall: 0.3490 - iou_score: 0.2409 - precision: 0.5266 - val_loss: -0.1031 - val_accuracy: 0.9952 - val_iou_seg: 0.8987 - val_mean_io_u: 0.5553 - val_recall: 0.1759 - val_iou_score: 0.1013 - val_precision: 0.3648 - lr: 2.4787e-06
# Epoch 71/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2424 - accuracy: 0.9959 - iou_seg: 0.7590 - mean_io_u: 0.6018 - recall: 0.3491 - iou_score: 0.2410 - precision: 0.5267
# Epoch 71: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 107ms/step - loss: -0.2424 - accuracy: 0.9959 - iou_seg: 0.7590 - mean_io_u: 0.6018 - recall: 0.3491 - iou_score: 0.2410 - precision: 0.5267 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5553 - val_recall: 0.1760 - val_iou_score: 0.1014 - val_precision: 0.3644 - lr: 2.2429e-06
# Epoch 72/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2424 - accuracy: 0.9959 - iou_seg: 0.7589 - mean_io_u: 0.6018 - recall: 0.3492 - iou_score: 0.2411 - precision: 0.5273
# Epoch 72: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 106ms/step - loss: -0.2424 - accuracy: 0.9959 - iou_seg: 0.7589 - mean_io_u: 0.6018 - recall: 0.3492 - iou_score: 0.2411 - precision: 0.5273 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5553 - val_recall: 0.1759 - val_iou_score: 0.1014 - val_precision: 0.3644 - lr: 2.0294e-06
# Epoch 73/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2425 - accuracy: 0.9959 - iou_seg: 0.7589 - mean_io_u: 0.6019 - recall: 0.3492 - iou_score: 0.2411 - precision: 0.5275
# Epoch 73: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 99ms/step - loss: -0.2425 - accuracy: 0.9959 - iou_seg: 0.7589 - mean_io_u: 0.6019 - recall: 0.3492 - iou_score: 0.2411 - precision: 0.5275 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5554 - val_recall: 0.1760 - val_iou_score: 0.1014 - val_precision: 0.3644 - lr: 1.8363e-06
# Epoch 74/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2426 - accuracy: 0.9959 - iou_seg: 0.7588 - mean_io_u: 0.6019 - recall: 0.3493 - iou_score: 0.2412 - precision: 0.5278
# Epoch 74: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 99ms/step - loss: -0.2426 - accuracy: 0.9959 - iou_seg: 0.7588 - mean_io_u: 0.6019 - recall: 0.3493 - iou_score: 0.2412 - precision: 0.5278 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5554 - val_recall: 0.1759 - val_iou_score: 0.1014 - val_precision: 0.3644 - lr: 1.6616e-06
# Epoch 75/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2426 - accuracy: 0.9959 - iou_seg: 0.7588 - mean_io_u: 0.6019 - recall: 0.3493 - iou_score: 0.2412 - precision: 0.5279
# Epoch 75: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 99ms/step - loss: -0.2426 - accuracy: 0.9959 - iou_seg: 0.7588 - mean_io_u: 0.6019 - recall: 0.3493 - iou_score: 0.2412 - precision: 0.5279 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5554 - val_recall: 0.1759 - val_iou_score: 0.1014 - val_precision: 0.3643 - lr: 1.5034e-06
# Epoch 76/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2427 - accuracy: 0.9959 - iou_seg: 0.7587 - mean_io_u: 0.6019 - recall: 0.3494 - iou_score: 0.2413 - precision: 0.5282
# Epoch 76: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 11s 100ms/step - loss: -0.2427 - accuracy: 0.9959 - iou_seg: 0.7587 - mean_io_u: 0.6019 - recall: 0.3494 - iou_score: 0.2413 - precision: 0.5282 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5554 - val_recall: 0.1759 - val_iou_score: 0.1014 - val_precision: 0.3644 - lr: 1.3604e-06
# Epoch 77/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2427 - accuracy: 0.9959 - iou_seg: 0.7587 - mean_io_u: 0.6020 - recall: 0.3494 - iou_score: 0.2413 - precision: 0.5282
# Epoch 77: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 12s 103ms/step - loss: -0.2427 - accuracy: 0.9959 - iou_seg: 0.7587 - mean_io_u: 0.6020 - recall: 0.3494 - iou_score: 0.2413 - precision: 0.5282 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5554 - val_recall: 0.1759 - val_iou_score: 0.1014 - val_precision: 0.3643 - lr: 1.2309e-06
# Epoch 78/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2428 - accuracy: 0.9959 - iou_seg: 0.7586 - mean_io_u: 0.6020 - recall: 0.3495 - iou_score: 0.2414 - precision: 0.5284
# Epoch 78: val_iou_score did not improve from 0.11167
# ...
# Epoch 125/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 125: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 72s 634ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 1.0130e-08
# Epoch 126/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 126: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 72s 632ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 9.1660e-09
# Epoch 127/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 127: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 71s 622ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 8.2938e-09
# Epoch 128/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 128: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 71s 623ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 7.5045e-09
# Epoch 129/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 129: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 71s 627ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 6.7904e-09
# Epoch 130/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 130: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 71s 625ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 6.1442e-09
# Epoch 131/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 131: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 72s 627ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 5.5595e-09
# Epoch 132/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 132: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 68s 599ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 5.0304e-09
# Epoch 133/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 133: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 73s 637ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 4.5517e-09
# Epoch 134/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 134: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 69s 605ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 4.1186e-09
# Epoch 135/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 135: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 71s 620ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 3.7266e-09
# Epoch 136/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 136: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 111s 980ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 3.3720e-09
# Epoch 137/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 137: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 81s 712ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6023 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 3.0511e-09
# Epoch 138/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 138: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 80s 705ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 2.7608e-09
# Epoch 139/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 139: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 80s 701ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 2.4980e-09
# Epoch 140/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 140: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 79s 696ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 2.2603e-09
# Epoch 141/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 141: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 76s 670ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 2.0452e-09
# Epoch 142/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 142: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 76s 667ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 1.8506e-09
# Epoch 143/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 143: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 76s 667ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 1.6745e-09
# Epoch 144/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 144: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 76s 664ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 1.5151e-09
# Epoch 145/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 145: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 77s 677ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 1.3709e-09
# Epoch 146/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 146: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 74s 653ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 1.2405e-09
# Epoch 147/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 147: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 74s 648ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 1.1224e-09
# Epoch 148/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 148: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 74s 647ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 1.0156e-09
# Epoch 149/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 149: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 75s 658ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 9.1897e-10
# Epoch 150/150
# 114/114 [==============================] - ETA: 0s - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303
# Epoch 150: val_iou_score did not improve from 0.11167
# 114/114 [==============================] - 75s 658ms/step - loss: -0.2432 - accuracy: 0.9959 - iou_seg: 0.7582 - mean_io_u: 0.6022 - recall: 0.3498 - iou_score: 0.2418 - precision: 0.5303 - val_loss: -0.1032 - val_accuracy: 0.9952 - val_iou_seg: 0.8986 - val_mean_io_u: 0.5555 - val_recall: 0.1763 - val_iou_score: 0.1014 - val_precision: 0.3651 - lr: 8.3152e-10
# unet_model execution time is:  1:15:22.225836

# %%
predictions=model.predict(X_test)
predictions.shape
# Out:
# 13/13 [==============================] - 10s 226ms/step
# (391, 128, 128, 1)

# %%
predictions=(predictions>0.5).astype(np.int8)

# %%
def compute_iou(predictions, masks):
    intersection = np.logical_and(predictions, masks)
    union = np.logical_or(predictions, masks)
    iou = np.sum(intersection) / np.sum(union)
    return iou

def compute_mean_iou(predictions_list, masks_list):
    num_samples = len(predictions_list)
    total_iou = 0.0

    for i in range(num_samples):
        predictions = predictions_list[i]
        masks = masks_list[i]

        iou = compute_iou(predictions, masks)
        total_iou += iou

    mean_iou = total_iou / num_samples
    return mean_iou

# %%
compute_iou(predictions, y_test)
# Out:
# 0.13490616321149046

# %%
def plot_random_comparison(X_test, y_test, predictions):
    """Plot comparison between a randomly selected test image, its ground truth, and predicted segmentation mask."""
    # Generate a random index
    index = np.random.randint(0, len(X_test))
    print(str(index)+"\n")
    iou=compute_iou(y_test[index], predictions[index])
    
    plt.figure(figsize=(12, 4))
    
    # Plot the test image
    plt.subplot(1, 3, 1)
    plt.imshow(X_test[index,:,:,0:3])
    plt.title('Test Image')
    plt.axis('off')
    
    # Plot the ground truth mask
    plt.subplot(1, 3, 2)
    plt.imshow(y_test[index].squeeze(), cmap='gray')  # Use .squeeze() in case your mask has an extra dimension
    plt.title('Ground Truth Mask')
    plt.axis('off')
    
    # Plot the predicted mask
    plt.subplot(1, 3, 3)
    plt.imshow(predictions[index].squeeze(), cmap='gray')  # Use .squeeze() in case your prediction has an extra dimension
    plt.title(f'Predicted Mask {iou}')
    plt.axis('off')
    
    plt.show()

# %%
plot_random_comparison(X_test, y_test, predictions)
# Out:
# 322
